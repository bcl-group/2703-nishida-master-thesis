# %%
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.keras.optimizers import Adam
from matplotlib import pyplot as plt
from collections import deque
import random
import gym

# シミュレーション条件
EPISODES_MAX = 300000 # エピソード
STEPS_MAX = 30
DT = 0.01  # 時間ステップ
THRESHOLD = 0.05
THRESHOLD_REWARD = - 0.5
GOAL_POS = [0.0, 1.0]
THETA_INIT = 60 # [deg]
STEPS_INIT = 0
WARMUP_EPISODE = 15000
EVALUATION_EPISODE = 100
EVAL_INTERVAL = 1000
SUCCESS_THRESHOLD_HIGH = 0.8
SUCCESS_THRESHOLD_LOW = 0.5


# 制御対象
L = 1.0  # アームの長さ
THETA_MAX = 180
THETA_MIN = 0

# 強化学習のパラメータ
ACTION_MIN = - 200 # [deg/s]
ACTION_MAX = 18000 # [deg/s]
STATE_MIN = - 1.0
STATE_MAX = 1.0
STATE_THETA_MAX = np.pi
REWARD_G = 30
REWARD_D = 300
REWARD_P_JE = 0.00000001
REWARD_JE_LIM = 0.0000001
REWARD_P_V = 10.0
REWARD_P_T = 0.3
REWARD_STD_V = 50.0
REWARD_STD_D = 10.0
REWARD_STD_J = 10
TIME_PUNISH = 0.3
ALPHA = 0.5
BUFFER_SIZE = 1000000 #30000 episodes分
WARMUP_SIZE = 200000
TRAIN_INTARVAL = 10
BATCH_SIZE = 128
SIGMA = 0.9
SOFT_TARGET_TAU = 0.02
HARD_TARGET_INTERVAL = 100
LOG_2PI = tf.constant(np.log(2.0 * np.pi), dtype=tf.float32)


# ニューラルネットワークのパラメータ
GAMMA = 0.99
GAMMA_P = 0.003
GAMMA_V = 0.01
RAYER_INPUT = 3
RAYER_OUTPUT_V = 1
RAYER_OUTPUT_M = 1
RAYER_OUTPUT_S = 1
RAYER_HIDDEN =32

# データ保存
SAVE_INTERVAL = 10000  # 1000エピソードごとに詳細データを保存

tf.debugging.set_log_device_placement(True)
# Out:
# 2025-07-14 14:07:58.855564: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752469678.867043    3756 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752469678.870469    3756 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752469678.879837    3756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752469678.879847    3756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752469678.879849    3756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752469678.879850    3756 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-14 14:07:58.882938: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1752469681.094906    3756 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1020 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:05:00.0, compute capability: 8.6

# %%
import tensorflow as tf

# ログを詳細に出力
tf.debugging.set_log_device_placement(True)

# GPUを使った行列演算
a = tf.constant([[1.0]])
b = tf.constant([[2.0]])
c = a @ b
print(c)
# Out:
# tf.Tensor([[2.]], shape=(1, 1), dtype=float32)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class OneJointReachingEnv(gym.Env):
    """1関節アームのリーチング運動環境"""

    def __init__(self):
        super().__init__()

        # シミュレーションパラメータ（外部定義が必要）
        self.dt = DT                          # 時間刻み幅
        self.l = L                            # アームの長さ
        self.max_steps = STEPS_MAX            # 最大ステップ数
        self.goal_threshold = THRESHOLD       # ゴール判定閾値
        self.reward_j = 0          # 躍度ペナルティ重み

        # 状態空間：[角度, 角速度, 経過時間]
        self.observation_space = gym.spaces.Box(
            low=np.array([STATE_MIN, STATE_MIN, 0]),
            high=np.array([STATE_MAX, STATE_MAX, STATE_MAX]),
            shape=(3,), dtype=np.float32
        )
        
        # # 状態空間：[角度, 角速度, 経過時間]
        # self.observation_space = gym.spaces.Box(
        #     low=np.array([STATE_THETA_MIN, ACTION_MIN, 0]),
        #     high=np.array([STATE_THETA_MAX, ACTION_MAX, 1]),
        #     shape=(3,), dtype=np.float32
        # )

        # # アクション空間：角速度（ラジアン）
        # self.action_space = gym.spaces.Box(
        #     low=np.radians(ACTION_MIN),
        #     high=np.radians(ACTION_MAX),
        #     shape=(1,), dtype=np.float32
        # )
        
        # アクション空間：関節角度
        self.action_space = gym.spaces.Box(
            low=np.radians(THETA_MIN),
            high=np.radians(THETA_MAX),
            shape=(1,), dtype=np.float32
        )

        # 目標座標
        self.goal_pos = np.array(GOAL_POS)

        self.reset()

    def set_penalty_weight(self, new_weight):
        """躍度ペナルティの重みを外部から設定"""
        self.reward_j = new_weight

    def reached_goal(self, dist_to_goal):
        """目標まで到達したかを判定"""
        return dist_to_goal <= self.goal_threshold

    def _get_obs(self):
        """現在の観測状態を返す"""
        theta_scaled = self.theta / STATE_THETA_MAX
        theta_vel_scaled = self.theta_vel / np.radians(ACTION_MAX)
        return np.array([theta_scaled, theta_vel_scaled, self.steps / self.max_steps], dtype=np.float32)

    def calicuram(self, episode):
        """カスタム報酬調整用関数（用途に応じて利用）"""
        return (episode / EPISODES_MAX) * 20

    def reset(self):
        """環境のリセット"""
        self.theta = np.radians(THETA_INIT)
        self.steps = STEPS_INIT

        self.theta_vel = 0.0
        self.theta_acc = 0.0
        self.theta_jerk = 0.0

        self.jerk_sum = 0.0
        self.jerk_mem = 0.0
        self.reward_dist = 0.0

        return self._get_obs()

    def step(self, action):
        """1ステップの実行"""

        # 直前の状態を記録
        prev_theta = self.theta
        prev_vel = self.theta_vel
        prev_acc = self.theta_acc

        # # 角度の更新（クリッピングあり）
        # self.theta += np.clip(action[0], np.radians(ACTION_MIN), np.radians(ACTION_MAX)) * self.dt
        # self.theta = np.clip(self.theta, THETA_MIN, np.radians(THETA_MAX))
        
        # 角度の更新（クリッピングあり）
        self.theta = np.clip(action[0], THETA_MIN, np.radians(THETA_MAX))

        # 動力学の更新（速度・加速度・躍度）
        self.update_dynamics(prev_theta, prev_vel, prev_acc)

        # 躍度の累積
        self.jerk_sum += self.dt * self.theta_jerk ** 2
        self.steps += 1

        # 手先位置と目標までの距離
        hand_pos = self.l * np.array([np.cos(self.theta), np.sin(self.theta)])
        dist_to_goal = np.linalg.norm(hand_pos - self.goal_pos)

        # 報酬内訳
        if self.steps < self.max_steps:
            reward_components = {
                "reward_dist": 0.0,
                "penalty_jerk": 0.0,
                "penalty_vel": 0.0,
                "penalty_time": 0.0,
            }
        
        else:
            reward_components = {
                "reward_dist":  - REWARD_D *dist_to_goal*dist_to_goal,
                # "penalty_jerk": 0.0,
                "penalty_jerk": - self.reward_j * self.jerk_sum,
                # "penalty_vel":  REWARD_P_V * np.exp(-self.theta_vel*self.theta_vel / 2* REWARD_STD_V**2),
                "penalty_vel":  0.0,
                "penalty_time": 0.0
            }

        # 合計報酬
        reward = sum(reward_components.values())

        # 終了条件
        done = self.steps >= self.max_steps

        # デバッグ用情報
        info = {
            "hand_pos": hand_pos,
            "theta_vel": self.theta_vel,
            "theta_acc": self.theta_acc,
            "theta_jerk": self.theta_jerk,
            "dist_to_goal": dist_to_goal,
            "reward_total": reward,
            "rate_jerk": 100* self.reward_j/REWARD_JE_LIM,
            **reward_components
        }

        return self._get_obs(), reward, done, info

    def update_dynamics(self, prev_theta, prev_vel, prev_acc):
        """関節の運動量（速度・加速度・躍度）の更新"""
        self.theta_vel = (self.theta - prev_theta) / self.dt
        self.theta_acc = (self.theta_vel - prev_vel) / self.dt
        self.theta_jerk = (self.theta_acc - prev_acc) / self.dt

# %%
class PolicyModel(keras.Model):
    """Soft Actor-Critic 用の方策モデル（Squashed Gaussian）"""

    def __init__(self, action_space):
        super().__init__()
        self.action_space = action_space

        # アクション空間のスケーリング情報
        self.action_center = (action_space.high + action_space.low) / 2.0
        self.action_scale = (action_space.high - action_space.low) / 2.0

        # ネットワーク構造（入力3次元：角度・速度・時間）
        self.hidden1 = keras.layers.Dense(RAYER_HIDDEN, activation="relu", input_shape=(3,))
        self.hidden2 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.hidden3 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")

        # 平均と対数標準偏差（出力次元はアクション次元）
        self.mean_layer = keras.layers.Dense(action_space.shape[0], activation="linear")
        self.log_std_layer = keras.layers.Dense(action_space.shape[0], activation="linear")

        # オプティマイザ（学習率は適宜調整）
        self.optimizer = Adam(learning_rate=0.003)

    def call(self, inputs, training=False):
        """平均と標準偏差を出力（正規分布のパラメータ）"""
        x = self.hidden1(inputs)
        x = self.hidden2(x)
        x = self.hidden3(x)

        mean = self.mean_layer(x)
        log_std = tf.clip_by_value(self.log_std_layer(x), -20.0, 2.0)  # 安定化のためクリップ
        stddev = tf.exp(log_std)

        return mean, stddev

    @tf.function
    def sample_actions(self, states, training=False):
        """アクションをサンプル（Squashed Gaussian Policy）"""
        mean, stddev = self(states, training)
        normal_sample = tf.random.normal(mean.shape)

        # 学習時はサンプル、推論時は平均のみ
        raw_action = mean + stddev * normal_sample if training else mean
        squashed_action = tf.tanh(raw_action)  # [-1, 1] に変換

        return squashed_action, mean, stddev, raw_action

    def sample_action(self, states, training=False):
        """環境用にアクションをスケーリングして返す"""
        states = states.reshape(1, -1)
        squashed_action, _, _, _ = self.sample_actions(states, training)
        squashed_action = squashed_action.numpy()[0]

        # 環境用のスケーリング（実アクション空間へ）
        env_action = squashed_action * self.action_scale + self.action_center
        return env_action, squashed_action

# %%
class DualQNetwork(keras.Model):
    def __init__(self):
        super().__init__()

        # Q1ネットワーク（入力: 状態3次元 + アクション1次元 = 4次元）
        self.dense1 = keras.layers.Dense(RAYER_HIDDEN, activation="relu", input_shape=(4,))
        self.dense2 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense3 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense4 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.value1 = keras.layers.Dense(RAYER_HIDDEN, activation="linear")

        # Q2ネットワーク（同様に）
        self.dense5 = keras.layers.Dense(RAYER_HIDDEN, activation="relu", input_shape=(4,))
        self.dense6 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense7 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense8 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.value2 = keras.layers.Dense(RAYER_OUTPUT_V, activation="linear")

        # 最適化手法
        self.optimizer = Adam(learning_rate=0.003)

    def call(self, states, actions, training=False):
        x = tf.concat([states, actions], axis=1)  # shape: (batch, 4)

        # Q1分岐
        x1 = self.dense1(x)
        x1 = self.dense2(x1)
        x1 = self.dense3(x1)
        x1 = self.dense4(x1)
        q1 = self.value1(x1)

        # Q2分岐
        x2 = self.dense5(x)
        x2 = self.dense6(x2)
        x2 = self.dense7(x2)
        x2 = self.dense8(x2)
        q2 = self.value2(x2)

        return q1, q2

# %%
@tf.function
def compute_logpi(mean, stddev, action):
    """通常の正規分布における log π(a|s) を計算"""
    log2pi = tf.constant(np.log(2.0 * np.pi), dtype=tf.float32)#定数を定めるときに用いる
    log_prob = -0.5 * ((action - mean) / stddev) ** 2 \
               - tf.math.log(stddev) \
               - 0.5 * log2pi #logpiをlogにする
    return tf.reduce_sum(log_prob, axis=1, keepdims=True)#actionが多次元で違う確率分布によって出力される場合、logで足し合わせ

# Squashed Gaussian Policy時の logπ(a|s)

@tf.function
def compute_logpi_sgp(mean, stddev, pre_tanh_action):
    """Squashed Gaussian Policy の log π(a|s) を計算"""
    logpi = compute_logpi(mean, stddev, pre_tanh_action)
    # tanhの逆変換でlogπ修正（確率分布が圧縮されているから、それを伸ばす）
    log_det_jacobian = tf.reduce_sum(tf.math.log(1 - tf.tanh(pre_tanh_action) ** 2 + 1e-6), axis=1, keepdims=True)
    return logpi - log_det_jacobian

def update_model(
        policy_model, 
        q_model, 
        target_q_model,
        experiences,
        BATCH_SIZE,
        SIGMA,
        log_alpha,
        log_alpha_optimizer,  # 追加
        soft_target_tau,
        hard_target_interval,
        target_entropy,
        all_train_count,
    ):

    """SACアルゴリズムの1ステップ更新"""
    alpha = tf.math.exp(log_alpha)#何を計算してる？

    # ミニバッチのサンプリング
    batchs = random.sample(experiences, BATCH_SIZE)
    states = np.asarray([e["state"] for e in batchs])
    n_states = np.asarray([e["n_state"] for e in batchs])
    actions = np.asarray([e["action"] for e in batchs])
    rewards = np.asarray([e["reward"] for e in batchs]).reshape((-1, 1))
    dones = np.asarray([e["done"] for e in batchs]).reshape((-1, 1))

    # --- 次状態からアクションとlogπの計算
    n_actions, n_means, n_stddevs, n_action_orgs = policy_model.sample_actions(n_states)
    n_logpi = compute_logpi_sgp(n_means, n_stddevs, n_action_orgs)

    # --- 目標Q値の計算
    n_q1, n_q2 = target_q_model(n_states, n_actions)
    q_vals = rewards + (1 - dones) * GAMMA * tf.minimum(n_q1, n_q2) - (alpha * n_logpi)#logpi(at+1|st+1)になるらしい

    # --- Qモデルの学習
    with tf.GradientTape() as tape:
        q1, q2 = q_model(states, actions, training=True)
        loss1 = tf.reduce_mean(tf.square(q_vals - q1))#2乗してバッチごとに平均
        loss2 = tf.reduce_mean(tf.square(q_vals - q2))
        q_loss = loss1 + loss2#何で和を取るの？

    grads = tape.gradient(q_loss, q_model.trainable_variables)
    q_model.optimizer.apply_gradients(zip(grads, q_model.trainable_variables))

    # --- ポリシーの学習
    with tf.GradientTape() as tape:
        selected_actions, means, stddevs, action_orgs = policy_model.sample_actions(states, training=True)
        logpi = compute_logpi_sgp(means, stddevs, action_orgs)
        q1, q2 = q_model(states, selected_actions)
        q_min = tf.minimum(q1, q2)
        policy_loss = -tf.reduce_mean(q_min - tf.stop_gradient(alpha) * logpi)#バッチ学習を行なっているため個々の損失ではなく、バッチ全体の平均損失について計算

    grads = tape.gradient(policy_loss, policy_model.trainable_variables)#lossの計算に関与したモデルの学習可能変数に対する勾配を求める. policy_model.trainable_variablesはモデル内部の 重みやバイアスなどの学習対象の変数
    policy_model.optimizer.apply_gradients(zip(grads, policy_model.trainable_variables))

    # --- log_alphaの更新
    with tf.GradientTape() as tape:
        entropy_diff = -logpi - target_entropy
        log_alpha_loss = tf.reduce_mean(tf.exp(log_alpha) * entropy_diff)

    grad = tape.gradient(log_alpha_loss, [log_alpha])
    log_alpha_optimizer.apply_gradients(zip(grad, [log_alpha]))

    # --- ソフトターゲット更新
    target_q_model.set_weights([
        (1 - soft_target_tau) * w + soft_target_tau * t 
        for w, t in zip(target_q_model.get_weights(), q_model.get_weights())
    ])

    # --- ハードターゲット同期（一定ステップごと）
    if all_train_count % hard_target_interval == 0:
        target_q_model.set_weights(q_model.get_weights())

    return policy_loss, q_loss

# %%
def train_main():
    # 保存用ディレクトリの作成
    result_dir = "results_5_14"
    os.makedirs(result_dir, exist_ok=True)
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    max_episodes = EPISODES_MAX

    # 早期終了条件の確認
    def check_early_stop(history, episode):
        if episode < 1000:
            return False
        recent = [r["total"] for r in history[-100:]]
        avg_reward = np.mean(recent)
        print(f"EarlyStop Check @Ep{episode}: AvgReward={avg_reward:.4f}")
        return avg_reward > THRESHOLD_REWARD

    # 初期化
    env = OneJointReachingEnv()
    env.set_penalty_weight(0)
    penalty_weight = 0

    target_entropy = -1 * env.observation_space.shape[0]
    policy_model = PolicyModel(env.action_space)
    q_model, target_q_model = DualQNetwork(), DualQNetwork()

    # モデル初期化
    dummy_state = np.random.normal(0, 0.1, size=(1,) + env.observation_space.shape)
    dummy_action = np.random.normal(0, 0.1, size=(1,) + env.action_space.shape)
    q_model(dummy_state, dummy_action)
    target_q_model(dummy_state, dummy_action)
    target_q_model.set_weights(q_model.get_weights())

    log_alpha = tf.Variable(0.0, dtype=tf.float32)
    alpha_optimizer = tf.keras.optimizers.Adam(learning_rate=3e-4)

    # 経験バッファと履歴
    replay_buffer = deque(maxlen=BUFFER_SIZE)
    history_rewards, history_metrics, history_metrics_y, episode_results = [], [], [], []

    total_steps, train_count = 0, 0
    is_last_episode = False

    for episode in range(max_episodes):
        state = np.asarray(env.reset())
        done = False
        total_reward = 0
        rate_jerk = 0
        step = 0
        metrics_list = []
        success = False

        is_last_episode = (episode == max_episodes - 1)

        # 初期状態記録
        step_data = [f"0 0.00 {L * np.cos(state[0]*STATE_THETA_MAX):.4f} {L * np.sin(state[0]*STATE_THETA_MAX):.4f} {np.degrees(state[0]*STATE_THETA_MAX):.4f} 0.0 0.0 0.0"]
        if is_last_episode:
            step_data_eval = [step_data[0]]

        while not done:
            # 方策に従って行動を選択
            action, pre_tanh = policy_model.sample_action(state, training=not is_last_episode)
            next_state, reward, done, info = env.step(action)
            next_state = np.asarray(next_state)

            # ログ出力
            step += 1
            total_reward += reward
            log_line = (f"{step} {step * DT:.2f} {info['hand_pos'][0]:.4f} {info['hand_pos'][1]:.4f} "
                        f"{np.degrees(next_state[0]*STATE_THETA_MAX):.4f} {np.degrees(info['theta_vel']):.4f} "
                        f"{np.degrees(info['theta_acc']):.4f} {np.degrees(info['theta_jerk']):.4f}")
            step_data.append(log_line)
            if is_last_episode:
                step_data_eval.append(log_line)

            # 学習用データ蓄積と更新
            if not is_last_episode:
                replay_buffer.append({
                    "state": state,
                    "action": pre_tanh,
                    "reward": reward,
                    "n_state": next_state,
                    "done": done,
                })
                if len(replay_buffer) >= WARMUP_SIZE and total_steps % TRAIN_INTARVAL == 0:
                    metrics = update_model(
                        policy_model, q_model, target_q_model,
                        replay_buffer, BATCH_SIZE, SIGMA,
                        log_alpha, alpha_optimizer,
                        soft_target_tau=0.02, hard_target_interval=100,
                        target_entropy=target_entropy,
                        all_train_count=train_count
                    )
                    train_count += 1
                    metrics_list.append(metrics)

            state = next_state
            total_steps += 1

        # ゴール達成判定
        if env.reached_goal(info["dist_to_goal"]):
            success = True
        episode_results.append(success)

        # 報酬履歴の保存
        history_rewards.append({
            "total": total_reward,
            "reward_dist": info.get("reward_dist", 0.0),
            "penalty_jerk": info.get("penalty_jerk", 0.0),
            "penalty_vel": info.get("penalty_vel", 0.0),
            "penalty_time": info.get("penalty_time", 0.0),
            "rate_jerk": info.get("rate_jerk", 0.0)
        })
        if metrics_list:
            history_metrics.append(np.mean(metrics_list, axis=0))
            history_metrics_y.append(episode)

        # 成功率に基づいたペナルティ調整
        if episode == WARMUP_EPISODE:
            penalty_weight = REWARD_P_JE
            env.set_penalty_weight(penalty_weight)
        
        if episode >= WARMUP_EPISODE and (episode + 1) % EVAL_INTERVAL == 0:
            success_rate = sum(episode_results[-EVALUATION_EPISODE:]) / EVALUATION_EPISODE
            print(f"[Episode {episode+1}] Success Rate: {success_rate:.2%}")
            if success_rate >= SUCCESS_THRESHOLD_HIGH:
                if penalty_weight <= REWARD_JE_LIM:
                    penalty_weight *= 1.0
                    print(f"-> 躍度ペナルティ重みを増加")
                else:
                    print("upper-limit")
            elif success_rate <= SUCCESS_THRESHOLD_LOW:
                penalty_weight *= 1.0
                print(f"-> 躍度ペナルティ重みを減少")
            
            else:
                print(f"-> 躍度ペナルティ重みを維持")
            
               
            if (penalty_weight > REWARD_JE_LIM):
                penalty_weight = REWARD_JE_LIM
                       
            env.set_penalty_weight(penalty_weight)

        # ログファイル保存
        if (episode + 1) % SAVE_INTERVAL == 0:
            with open(f"{result_dir}/{timestamp}_data_{episode+1}.csv", "w") as f:
                f.write("Step Time HandX HandY Theta Theta_vel Theta_ac Theta_je\n")
                f.write("\n".join(step_data))

        if is_last_episode:
            with open(f"{result_dir}/{timestamp}_eval_last_episode.csv", "w") as f:
                f.write("Step Time HandX HandY Theta Theta_vel Theta_ac Theta_je\n")
                f.write("\n".join(step_data_eval))
            break
            
        rate_jerk = info['rate_jerk']
        if episode % 100 == 0:
            print(f"Episode: {episode+1} Total Reward: {total_reward:.2f} action: {action} rate_jerk: {rate_jerk:.4f}" )

        #早期終了条件チェック
        # if (episode + 1) % 100 == 0 and penalty_weight >= REWARD_JE_LIM:
        if (episode + 1) % 100 == 0 and episode > 20000:
            if check_early_stop(history_rewards, episode + 1):
                print(f"✅ 準最適方策を獲得: Ep{episode+1}で学習終了")
                max_episodes = episode + 2
                

    # 報酬履歴の保存
    with open(f"{result_dir}/{timestamp}_data_sum.csv", "w") as f:
        f.write("Episode TotalReward RewardDist PenaltyJerk PenaltyVel PenaltyTime\n")
        for i, r in enumerate(history_rewards):
            f.write(f"{i+1} {r['total']:.4f} {r['reward_dist']:.4f} "
                    f"{r['penalty_jerk']:.4f} {r['penalty_vel']:.4f} {r['penalty_time']:.4f} {r['rate_jerk']:.4f}\n")

    print("データの保存が完了しました！")
    return policy_model, history_rewards, history_metrics, history_metrics_y

# %%
model, history_rewards, history_metrics, history_metrics_y = train_main()
# Out:
# /home/hera/rikunishida114/2703-nishida-master-thesis/.venv/lib/python3.12/site-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Episode: 1 Total Reward: -0.24 action: [1.5426949] rate_jerk: 0.0000
# Episode: 101 Total Reward: -0.02 action: [1.5636786] rate_jerk: 0.0000
# Episode: 201 Total Reward: -0.00 action: [1.5669742] rate_jerk: 0.0000
# Episode: 301 Total Reward: -117.49 action: [2.207296] rate_jerk: 0.0000
# Episode: 401 Total Reward: -547.68 action: [0.08730888] rate_jerk: 0.0000
# Episode: 501 Total Reward: -101.59 action: [0.98032975] rate_jerk: 0.0000
# Episode: 601 Total Reward: -121.49 action: [2.2184138] rate_jerk: 0.0000
# Episode: 701 Total Reward: -577.19 action: [0.03802609] rate_jerk: 0.0000
# Episode: 801 Total Reward: -145.71 action: [0.85893977] rate_jerk: 0.0000
# Episode: 901 Total Reward: -181.79 action: [2.370363] rate_jerk: 0.0000
# Episode: 1001 Total Reward: -491.87 action: [0.18121028] rate_jerk: 0.0000
# Episode: 1101 Total Reward: -471.95 action: [0.21507072] rate_jerk: 0.0000
# Episode: 1201 Total Reward: -331.33 action: [2.6773047] rate_jerk: 0.0000
# Episode: 1301 Total Reward: -449.76 action: [2.888494] rate_jerk: 0.0000
# Episode: 1401 Total Reward: -227.13 action: [2.4710112] rate_jerk: 0.0000
# Episode: 1501 Total Reward: -362.36 action: [2.7343621] rate_jerk: 0.0000
# Episode: 1601 Total Reward: -29.64 action: [1.2551731] rate_jerk: 0.0000
# Episode: 1701 Total Reward: -220.87 action: [0.6839913] rate_jerk: 0.0000
# Episode: 1801 Total Reward: -520.06 action: [3.0079598] rate_jerk: 0.0000
# Episode: 1901 Total Reward: -16.98 action: [1.8092947] rate_jerk: 0.0000
# Episode: 2001 Total Reward: -508.88 action: [2.9891396] rate_jerk: 0.0000
# Episode: 2101 Total Reward: -583.56 action: [3.1141825] rate_jerk: 0.0000
# Episode: 2201 Total Reward: -280.37 action: [2.5797791] rate_jerk: 0.0000
# Episode: 2301 Total Reward: -329.72 action: [0.46729672] rate_jerk: 0.0000
# Episode: 2401 Total Reward: -326.78 action: [2.6688066] rate_jerk: 0.0000
# Episode: 2501 Total Reward: -448.27 action: [2.8859367] rate_jerk: 0.0000
# Episode: 2601 Total Reward: -124.45 action: [2.2265482] rate_jerk: 0.0000
# Episode: 2701 Total Reward: -11.89 action: [1.3713591] rate_jerk: 0.0000
# Episode: 2801 Total Reward: -249.27 action: [2.5172644] rate_jerk: 0.0000
# Episode: 2901 Total Reward: -529.15 action: [3.0232382] rate_jerk: 0.0000
# Episode: 3001 Total Reward: -365.67 action: [0.40122068] rate_jerk: 0.0000
# Episode: 3101 Total Reward: -47.13 action: [1.1718152] rate_jerk: 0.0000
# Episode: 3201 Total Reward: -21.02 action: [1.3052882] rate_jerk: 0.0000
# Episode: 3301 Total Reward: -343.59 action: [0.44156516] rate_jerk: 0.0000
# Episode: 3401 Total Reward: -146.49 action: [0.8569445] rate_jerk: 0.0000
# Episode: 3501 Total Reward: -51.17 action: [1.1548076] rate_jerk: 0.0000
# Episode: 3601 Total Reward: -0.50 action: [1.6117599] rate_jerk: 0.0000
# Episode: 3701 Total Reward: -558.07 action: [3.0716553] rate_jerk: 0.0000
# Episode: 3801 Total Reward: -398.28 action: [2.7987103] rate_jerk: 0.0000
# Episode: 3901 Total Reward: -2.93 action: [1.6696256] rate_jerk: 0.0000
# Episode: 4001 Total Reward: -174.75 action: [0.78771824] rate_jerk: 0.0000
# Episode: 4101 Total Reward: -173.11 action: [0.79159987] rate_jerk: 0.0000
# Episode: 4201 Total Reward: -413.13 action: [0.31672037] rate_jerk: 0.0000
# Episode: 4301 Total Reward: -45.57 action: [1.9630598] rate_jerk: 0.0000
# Episode: 4401 Total Reward: -485.56 action: [2.9496832] rate_jerk: 0.0000
# Episode: 4501 Total Reward: -544.74 action: [3.0493543] rate_jerk: 0.0000
# Episode: 4601 Total Reward: -70.95 action: [2.0620284] rate_jerk: 0.0000
# Episode: 4701 Total Reward: -1.26 action: [1.5059183] rate_jerk: 0.0000
# Episode: 4801 Total Reward: -55.79 action: [1.1361461] rate_jerk: 0.0000
# Episode: 4901 Total Reward: -14.02 action: [1.354185] rate_jerk: 0.0000
# Episode: 5001 Total Reward: -68.40 action: [1.0886332] rate_jerk: 0.0000
# Episode: 5101 Total Reward: -353.98 action: [0.42249417] rate_jerk: 0.0000
# Episode: 5201 Total Reward: -447.96 action: [0.25619018] rate_jerk: 0.0000
# Episode: 5301 Total Reward: -475.89 action: [2.933237] rate_jerk: 0.0000
# Episode: 5401 Total Reward: -408.54 action: [2.8168144] rate_jerk: 0.0000
# Episode: 5501 Total Reward: -178.43 action: [0.7790695] rate_jerk: 0.0000
# Episode: 5601 Total Reward: -18.23 action: [1.3236761] rate_jerk: 0.0000
# Episode: 5701 Total Reward: -545.94 action: [3.051363] rate_jerk: 0.0000
# Episode: 5801 Total Reward: -365.54 action: [2.7401214] rate_jerk: 0.0000
# Episode: 5901 Total Reward: -189.73 action: [0.7529309] rate_jerk: 0.0000
# Episode: 6001 Total Reward: -501.94 action: [0.16417706] rate_jerk: 0.0000
# Episode: 6101 Total Reward: -455.63 action: [2.8986] rate_jerk: 0.0000
# Episode: 6201 Total Reward: -3.75 action: [1.4589498] rate_jerk: 0.0000
# Episode: 6301 Total Reward: -273.93 action: [0.5745451] rate_jerk: 0.0000
# Episode: 6401 Total Reward: -242.64 action: [2.5035758] rate_jerk: 0.0000
# Episode: 6501 Total Reward: -156.15 action: [0.83270997] rate_jerk: 0.0000
# Episode: 6601 Total Reward: -193.52 action: [0.7443181] rate_jerk: 0.0000
# Episode: 6701 Total Reward: -305.90 action: [0.51227283] rate_jerk: 0.0000
# Episode: 6801 Total Reward: -0.39 action: [1.5349443] rate_jerk: 0.0000
# Episode: 6901 Total Reward: -1.01 action: [1.5128723] rate_jerk: 0.0000
# Episode: 7001 Total Reward: -14.84 action: [1.3478876] rate_jerk: 0.0000
# Episode: 7101 Total Reward: -13.09 action: [1.3615584] rate_jerk: 0.0000
# Episode: 7201 Total Reward: -18.04 action: [1.324952] rate_jerk: 0.0000
# Episode: 7301 Total Reward: -0.44 action: [1.5326648] rate_jerk: 0.0000
# Episode: 7401 Total Reward: -6.40 action: [1.4246327] rate_jerk: 0.0000
# Episode: 7501 Total Reward: -8.80 action: [1.742279] rate_jerk: 0.0000
# Episode: 7601 Total Reward: -0.04 action: [1.5594839] rate_jerk: 0.0000
# Episode: 7701 Total Reward: -0.01 action: [1.5651866] rate_jerk: 0.0000
# Episode: 7801 Total Reward: -10.89 action: [1.7616397] rate_jerk: 0.0000
# Episode: 7901 Total Reward: -4.62 action: [1.4465795] rate_jerk: 0.0000
# Episode: 8001 Total Reward: -1.42 action: [1.5019705] rate_jerk: 0.0000
# Episode: 8101 Total Reward: -3.65 action: [1.4605011] rate_jerk: 0.0000
# Episode: 8201 Total Reward: -0.85 action: [1.5175056] rate_jerk: 0.0000
# Episode: 8301 Total Reward: -4.18 action: [1.6888506] rate_jerk: 0.0000
# Episode: 8401 Total Reward: -43.48 action: [1.1877592] rate_jerk: 0.0000
# Episode: 8501 Total Reward: -8.90 action: [1.3983861] rate_jerk: 0.0000
# Episode: 8601 Total Reward: -0.01 action: [1.5648175] rate_jerk: 0.0000
# Episode: 8701 Total Reward: -0.15 action: [1.5487682] rate_jerk: 0.0000
# Episode: 8801 Total Reward: -0.07 action: [1.555913] rate_jerk: 0.0000
# Episode: 8901 Total Reward: -11.30 action: [1.7652214] rate_jerk: 0.0000
# Episode: 9001 Total Reward: -17.85 action: [1.8153291] rate_jerk: 0.0000
# Episode: 9101 Total Reward: -10.23 action: [1.755701] rate_jerk: 0.0000
# Episode: 9201 Total Reward: -0.11 action: [1.5898249] rate_jerk: 0.0000
# Episode: 9301 Total Reward: -1.87 action: [1.4919107] rate_jerk: 0.0000
# Episode: 9401 Total Reward: -0.12 action: [1.5510447] rate_jerk: 0.0000
# Episode: 9501 Total Reward: -0.10 action: [1.5888034] rate_jerk: 0.0000
# Episode: 9601 Total Reward: -5.84 action: [1.7104194] rate_jerk: 0.0000
# Episode: 9701 Total Reward: -0.02 action: [1.5634469] rate_jerk: 0.0000
# Episode: 9801 Total Reward: -14.98 action: [1.3468878] rate_jerk: 0.0000
# Episode: 9901 Total Reward: -0.70 action: [1.5226095] rate_jerk: 0.0000
# Episode: 10001 Total Reward: -1.13 action: [1.5095028] rate_jerk: 0.0000
# Episode: 10101 Total Reward: -2.73 action: [1.6662567] rate_jerk: 0.0000
# Episode: 10201 Total Reward: -4.18 action: [1.4526297] rate_jerk: 0.0000
# Episode: 10301 Total Reward: -0.69 action: [1.6188146] rate_jerk: 0.0000
# Episode: 10401 Total Reward: -1.80 action: [1.6483754] rate_jerk: 0.0000
# Episode: 10501 Total Reward: -3.73 action: [1.6824106] rate_jerk: 0.0000
# Episode: 10601 Total Reward: -0.31 action: [1.6028415] rate_jerk: 0.0000
# Episode: 10701 Total Reward: -7.24 action: [1.7262745] rate_jerk: 0.0000
# Episode: 10801 Total Reward: -7.42 action: [1.7282327] rate_jerk: 0.0000
# Episode: 10901 Total Reward: -2.88 action: [1.6688263] rate_jerk: 0.0000
# Episode: 11001 Total Reward: -0.10 action: [1.5524023] rate_jerk: 0.0000
# Episode: 11101 Total Reward: -7.28 action: [1.4148549] rate_jerk: 0.0000
# Episode: 11201 Total Reward: -0.67 action: [1.5233674] rate_jerk: 0.0000
# Episode: 11301 Total Reward: -1.72 action: [1.6464756] rate_jerk: 0.0000
# Episode: 11401 Total Reward: -0.99 action: [1.6283816] rate_jerk: 0.0000
# Episode: 11501 Total Reward: -0.37 action: [1.5356511] rate_jerk: 0.0000
# Episode: 11601 Total Reward: -0.00 action: [1.5671636] rate_jerk: 0.0000
# Episode: 11701 Total Reward: -22.70 action: [1.8467183] rate_jerk: 0.0000
# Episode: 11801 Total Reward: -0.92 action: [1.6262429] rate_jerk: 0.0000
# Episode: 11901 Total Reward: -3.51 action: [1.6790768] rate_jerk: 0.0000
# Episode: 12001 Total Reward: -7.81 action: [1.7323635] rate_jerk: 0.0000
# Episode: 12101 Total Reward: -5.42 action: [1.7053003] rate_jerk: 0.0000
# Episode: 12201 Total Reward: -9.04 action: [1.7445635] rate_jerk: 0.0000
# Episode: 12301 Total Reward: -3.19 action: [1.6739434] rate_jerk: 0.0000
# Episode: 12401 Total Reward: -0.03 action: [1.5812731] rate_jerk: 0.0000
# Episode: 12501 Total Reward: -0.31 action: [1.6030024] rate_jerk: 0.0000
# Episode: 12601 Total Reward: -4.29 action: [1.6903808] rate_jerk: 0.0000
# Episode: 12701 Total Reward: -4.26 action: [1.690094] rate_jerk: 0.0000
# Episode: 12801 Total Reward: -1.93 action: [1.6511011] rate_jerk: 0.0000
# Episode: 12901 Total Reward: -2.72 action: [1.6660725] rate_jerk: 0.0000
# Episode: 13001 Total Reward: -0.48 action: [1.6105912] rate_jerk: 0.0000
# Episode: 13101 Total Reward: -0.14 action: [1.592069] rate_jerk: 0.0000
# Episode: 13201 Total Reward: -0.04 action: [1.5829709] rate_jerk: 0.0000
# Episode: 13301 Total Reward: -1.13 action: [1.6320828] rate_jerk: 0.0000
# Episode: 13401 Total Reward: -0.03 action: [1.5803353] rate_jerk: 0.0000
# Episode: 13501 Total Reward: -50.86 action: [1.9854898] rate_jerk: 0.0000
# Episode: 13601 Total Reward: -2.36 action: [1.4820561] rate_jerk: 0.0000
# Episode: 13701 Total Reward: -0.00 action: [1.5685232] rate_jerk: 0.0000
# Episode: 13801 Total Reward: -1.24 action: [1.6350447] rate_jerk: 0.0000
# Episode: 13901 Total Reward: -2.10 action: [1.6543978] rate_jerk: 0.0000
# Episode: 14001 Total Reward: -3.05 action: [1.6716563] rate_jerk: 0.0000
# Episode: 14101 Total Reward: -0.13 action: [1.5912557] rate_jerk: 0.0000
# Episode: 14201 Total Reward: -0.31 action: [1.5387896] rate_jerk: 0.0000
# Episode: 14301 Total Reward: -0.54 action: [1.5284982] rate_jerk: 0.0000
# Episode: 14401 Total Reward: -3.08 action: [1.4694864] rate_jerk: 0.0000
# Episode: 14501 Total Reward: -6.41 action: [1.71712] rate_jerk: 0.0000
# Episode: 14601 Total Reward: -5.06 action: [1.7007546] rate_jerk: 0.0000
# Episode: 14701 Total Reward: -24.67 action: [1.8585414] rate_jerk: 0.0000
# Episode: 14801 Total Reward: -0.04 action: [1.5819786] rate_jerk: 0.0000
# Episode: 14901 Total Reward: -11.52 action: [1.7670891] rate_jerk: 0.0000
# Episode: 15001 Total Reward: -8.90 action: [1.743212] rate_jerk: 0.0000
# Episode: 15101 Total Reward: -3136.08 action: [1.5222126] rate_jerk: 10.0000
# Episode: 15201 Total Reward: -2596.44 action: [1.5653766] rate_jerk: 10.0000
# Episode: 15301 Total Reward: -1870.45 action: [1.3914969] rate_jerk: 10.0000
# Episode: 15401 Total Reward: -2432.47 action: [1.4477085] rate_jerk: 10.0000
# Episode: 15501 Total Reward: -2188.72 action: [1.4701401] rate_jerk: 10.0000
# Episode: 15601 Total Reward: -2599.63 action: [1.608664] rate_jerk: 10.0000
# Episode: 15701 Total Reward: -2149.92 action: [1.5450808] rate_jerk: 10.0000
# Episode: 15801 Total Reward: -1136.45 action: [1.8824255] rate_jerk: 10.0000
# Episode: 15901 Total Reward: -1484.07 action: [1.920834] rate_jerk: 10.0000
# [Episode 16000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# Episode: 16001 Total Reward: -907.92 action: [1.7176768] rate_jerk: 10.0000
# Episode: 16101 Total Reward: -1511.57 action: [2.0219607] rate_jerk: 10.0000
# Episode: 16201 Total Reward: -547.83 action: [1.7096479] rate_jerk: 10.0000
# Episode: 16301 Total Reward: -1411.93 action: [1.7390032] rate_jerk: 10.0000
# Episode: 16401 Total Reward: -1754.82 action: [1.8308611] rate_jerk: 10.0000
# Episode: 16501 Total Reward: -1950.11 action: [1.269032] rate_jerk: 10.0000
# Episode: 16601 Total Reward: -2340.22 action: [1.1629119] rate_jerk: 10.0000
# Episode: 16701 Total Reward: -2089.69 action: [1.4247288] rate_jerk: 10.0000
# Episode: 16801 Total Reward: -2562.63 action: [1.3953241] rate_jerk: 10.0000
# Episode: 16901 Total Reward: -1892.48 action: [0.84472525] rate_jerk: 10.0000
# [Episode 17000] Success Rate: 9.00%
# -> 躍度ペナルティ重みを減少
# Episode: 17001 Total Reward: -1027.90 action: [1.5180234] rate_jerk: 10.0000
# Episode: 17101 Total Reward: -5738.46 action: [1.8435302] rate_jerk: 10.0000
# Episode: 17201 Total Reward: -99345.89 action: [1.7585561] rate_jerk: 10.0000
# Episode: 17301 Total Reward: -3231.89 action: [3.1415927] rate_jerk: 10.0000
# Episode: 17401 Total Reward: -3231.89 action: [3.1415927] rate_jerk: 10.0000
# Episode: 17501 Total Reward: -3231.89 action: [3.1415927] rate_jerk: 10.0000
# Episode: 17601 Total Reward: -1257.69 action: [0.00043952] rate_jerk: 10.0000
# Episode: 17701 Total Reward: -32355.31 action: [0.10204148] rate_jerk: 10.0000
# Episode: 17801 Total Reward: -40126.30 action: [0.45245016] rate_jerk: 10.0000
# Episode: 17901 Total Reward: -2740.16 action: [2.0820522] rate_jerk: 10.0000
# [Episode 18000] Success Rate: 1.00%
# -> 躍度ペナルティ重みを減少
# Episode: 18001 Total Reward: -150215.37 action: [0.07171392] rate_jerk: 10.0000
# Episode: 18101 Total Reward: -6028.82 action: [1.5012001] rate_jerk: 10.0000
# Episode: 18201 Total Reward: -1895.57 action: [2.254345] rate_jerk: 10.0000
# Episode: 18301 Total Reward: -410.23 action: [1.5427909] rate_jerk: 10.0000
# Episode: 18401 Total Reward: -925.47 action: [1.6909133] rate_jerk: 10.0000
# Episode: 18501 Total Reward: -125.98 action: [1.4809976] rate_jerk: 10.0000
# Episode: 18601 Total Reward: -972.19 action: [1.603073] rate_jerk: 10.0000
# Episode: 18701 Total Reward: -86.63 action: [1.4089873] rate_jerk: 10.0000
# Episode: 18801 Total Reward: -1188.06 action: [1.5993291] rate_jerk: 10.0000
# Episode: 18901 Total Reward: -1016.19 action: [1.7495284] rate_jerk: 10.0000
# [Episode 19000] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少
# Episode: 19001 Total Reward: -1448.10 action: [1.7727635] rate_jerk: 10.0000
# Episode: 19101 Total Reward: -1250.22 action: [1.8269924] rate_jerk: 10.0000
# Episode: 19201 Total Reward: -1135.40 action: [1.6104503] rate_jerk: 10.0000
# Episode: 19301 Total Reward: -1372.67 action: [2.0322108] rate_jerk: 10.0000
# Episode: 19401 Total Reward: -1285.93 action: [1.8972051] rate_jerk: 10.0000
# Episode: 19501 Total Reward: -1489.12 action: [1.8029875] rate_jerk: 10.0000
# Episode: 19601 Total Reward: -1672.39 action: [1.6978058] rate_jerk: 10.0000
# Episode: 19701 Total Reward: -1747.88 action: [1.7108612] rate_jerk: 10.0000
# Episode: 19801 Total Reward: -962.55 action: [1.9900253] rate_jerk: 10.0000
# Episode: 19901 Total Reward: -18134.24 action: [1.6403452] rate_jerk: 10.0000
# [Episode 20000] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少
# Episode: 20001 Total Reward: -1194.67 action: [1.8877988] rate_jerk: 10.0000
# EarlyStop Check @Ep20100: AvgReward=-1226.3973
# Episode: 20101 Total Reward: -1407.71 action: [1.7010412] rate_jerk: 10.0000
# EarlyStop Check @Ep20200: AvgReward=-1236.0928
# Episode: 20201 Total Reward: -498.97 action: [1.7063155] rate_jerk: 10.0000
# EarlyStop Check @Ep20300: AvgReward=-968.2179
# Episode: 20301 Total Reward: -460.46 action: [1.8589541] rate_jerk: 10.0000
# EarlyStop Check @Ep20400: AvgReward=-1131.9322
# Episode: 20401 Total Reward: -1223.55 action: [1.5285008] rate_jerk: 10.0000
# EarlyStop Check @Ep20500: AvgReward=-1040.7267
# Episode: 20501 Total Reward: -909.99 action: [1.521469] rate_jerk: 10.0000
# EarlyStop Check @Ep20600: AvgReward=-1182.9337
# Episode: 20601 Total Reward: -1255.50 action: [1.2994671] rate_jerk: 10.0000
# EarlyStop Check @Ep20700: AvgReward=-1374.1474
# Episode: 20701 Total Reward: -1511.47 action: [1.4323338] rate_jerk: 10.0000
# EarlyStop Check @Ep20800: AvgReward=-1479.8782
# Episode: 20801 Total Reward: -1107.64 action: [1.6558938] rate_jerk: 10.0000
# EarlyStop Check @Ep20900: AvgReward=-1312.7858
# Episode: 20901 Total Reward: -1280.85 action: [1.5736617] rate_jerk: 10.0000
# [Episode 21000] Success Rate: 46.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep21000: AvgReward=-1389.3809
# Episode: 21001 Total Reward: -1402.30 action: [1.478243] rate_jerk: 10.0000
# EarlyStop Check @Ep21100: AvgReward=-2349.7160
# Episode: 21101 Total Reward: -5418.66 action: [1.3585575] rate_jerk: 10.0000
# EarlyStop Check @Ep21200: AvgReward=-3437.3973
# Episode: 21201 Total Reward: -1619.31 action: [1.4613972] rate_jerk: 10.0000
# EarlyStop Check @Ep21300: AvgReward=-3400.4769
# Episode: 21301 Total Reward: -1188.14 action: [1.3327836] rate_jerk: 10.0000
# EarlyStop Check @Ep21400: AvgReward=-782.8991
# Episode: 21401 Total Reward: -720.69 action: [1.5912158] rate_jerk: 10.0000
# EarlyStop Check @Ep21500: AvgReward=-2417.9385
# Episode: 21501 Total Reward: -864.91 action: [1.6262908] rate_jerk: 10.0000
# EarlyStop Check @Ep21600: AvgReward=-13104.3167
# Episode: 21601 Total Reward: -46391.53 action: [2.6925855] rate_jerk: 10.0000
# EarlyStop Check @Ep21700: AvgReward=-15786.9750
# Episode: 21701 Total Reward: -7409.50 action: [1.6195799] rate_jerk: 10.0000
# EarlyStop Check @Ep21800: AvgReward=-4346.0054
# Episode: 21801 Total Reward: -1416.17 action: [1.6393415] rate_jerk: 10.0000
# EarlyStop Check @Ep21900: AvgReward=-2707.6966
# Episode: 21901 Total Reward: -11071.36 action: [0.40169895] rate_jerk: 10.0000
# [Episode 22000] Success Rate: 30.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep22000: AvgReward=-1669.3895
# Episode: 22001 Total Reward: -1485.17 action: [1.5400546] rate_jerk: 10.0000
# EarlyStop Check @Ep22100: AvgReward=-6623.2930
# Episode: 22101 Total Reward: -14149.43 action: [1.9059539] rate_jerk: 10.0000
# EarlyStop Check @Ep22200: AvgReward=-6993.2187
# Episode: 22201 Total Reward: -3017.64 action: [1.5755676] rate_jerk: 10.0000
# EarlyStop Check @Ep22300: AvgReward=-2855.2044
# Episode: 22301 Total Reward: -5238.05 action: [1.562374] rate_jerk: 10.0000
# EarlyStop Check @Ep22400: AvgReward=-10553.1617
# Episode: 22401 Total Reward: -8562.93 action: [1.4947257] rate_jerk: 10.0000
# EarlyStop Check @Ep22500: AvgReward=-11470.7753
# Episode: 22501 Total Reward: -12665.84 action: [2.0271845] rate_jerk: 10.0000
# EarlyStop Check @Ep22600: AvgReward=-13029.1844
# Episode: 22601 Total Reward: -13008.70 action: [1.4845402] rate_jerk: 10.0000
# EarlyStop Check @Ep22700: AvgReward=-11210.2761
# Episode: 22701 Total Reward: -7358.83 action: [1.7327423] rate_jerk: 10.0000
# EarlyStop Check @Ep22800: AvgReward=-34064.5942
# Episode: 22801 Total Reward: -2222.04 action: [1.3055408] rate_jerk: 10.0000
# EarlyStop Check @Ep22900: AvgReward=-2267.8557
# Episode: 22901 Total Reward: -4009.18 action: [0.2708695] rate_jerk: 10.0000
# [Episode 23000] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep23000: AvgReward=-6271.5406
# Episode: 23001 Total Reward: -20706.12 action: [1.556351] rate_jerk: 10.0000
# EarlyStop Check @Ep23100: AvgReward=-3329.7216
# Episode: 23101 Total Reward: -14440.98 action: [2.5074816] rate_jerk: 10.0000
# EarlyStop Check @Ep23200: AvgReward=-6773.9771
# Episode: 23201 Total Reward: -1812.13 action: [1.7091974] rate_jerk: 10.0000
# EarlyStop Check @Ep23300: AvgReward=-2669.7942
# Episode: 23301 Total Reward: -1793.13 action: [1.5202929] rate_jerk: 10.0000
# EarlyStop Check @Ep23400: AvgReward=-1504.9398
# Episode: 23401 Total Reward: -241.57 action: [1.5298266] rate_jerk: 10.0000
# EarlyStop Check @Ep23500: AvgReward=-766.4961
# Episode: 23501 Total Reward: -1563.97 action: [1.7151951] rate_jerk: 10.0000
# EarlyStop Check @Ep23600: AvgReward=-618.1442
# Episode: 23601 Total Reward: -1001.10 action: [2.1437402] rate_jerk: 10.0000
# EarlyStop Check @Ep23700: AvgReward=-733.1546
# Episode: 23701 Total Reward: -273.43 action: [1.7938447] rate_jerk: 10.0000
# EarlyStop Check @Ep23800: AvgReward=-768.4618
# Episode: 23801 Total Reward: -445.06 action: [1.3368238] rate_jerk: 10.0000
# EarlyStop Check @Ep23900: AvgReward=-845.6637
# Episode: 23901 Total Reward: -1023.05 action: [1.7853684] rate_jerk: 10.0000
# [Episode 24000] Success Rate: 1.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep24000: AvgReward=-1362.9055
# Episode: 24001 Total Reward: -408.08 action: [2.0579371] rate_jerk: 10.0000
# EarlyStop Check @Ep24100: AvgReward=-390.4993
# Episode: 24101 Total Reward: -345.10 action: [1.6993327] rate_jerk: 10.0000
# EarlyStop Check @Ep24200: AvgReward=-801.7046
# Episode: 24201 Total Reward: -1611.46 action: [1.9221325] rate_jerk: 10.0000
# EarlyStop Check @Ep24300: AvgReward=-1649.4640
# Episode: 24301 Total Reward: -1838.33 action: [1.7630606] rate_jerk: 10.0000
# EarlyStop Check @Ep24400: AvgReward=-1298.8112
# Episode: 24401 Total Reward: -1671.33 action: [1.7233541] rate_jerk: 10.0000
# EarlyStop Check @Ep24500: AvgReward=-806.1095
# Episode: 24501 Total Reward: -729.05 action: [1.8403409] rate_jerk: 10.0000
# EarlyStop Check @Ep24600: AvgReward=-553.1950
# Episode: 24601 Total Reward: -670.69 action: [1.9272225] rate_jerk: 10.0000
# EarlyStop Check @Ep24700: AvgReward=-765.9770
# Episode: 24701 Total Reward: -1700.85 action: [1.6632648] rate_jerk: 10.0000
# EarlyStop Check @Ep24800: AvgReward=-1697.3323
# Episode: 24801 Total Reward: -1842.80 action: [1.8813522] rate_jerk: 10.0000
# EarlyStop Check @Ep24900: AvgReward=-1787.5744
# Episode: 24901 Total Reward: -216.94 action: [1.5869409] rate_jerk: 10.0000
# [Episode 25000] Success Rate: 11.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep25000: AvgReward=-864.2951
# Episode: 25001 Total Reward: -1997.30 action: [2.0049613] rate_jerk: 10.0000
# EarlyStop Check @Ep25100: AvgReward=-1790.3975
# Episode: 25101 Total Reward: -1783.19 action: [1.851814] rate_jerk: 10.0000
# EarlyStop Check @Ep25200: AvgReward=-1442.4377
# Episode: 25201 Total Reward: -1550.27 action: [1.4631717] rate_jerk: 10.0000
# EarlyStop Check @Ep25300: AvgReward=-1814.4622
# Episode: 25301 Total Reward: -1964.02 action: [1.7678759] rate_jerk: 10.0000
# EarlyStop Check @Ep25400: AvgReward=-1925.5340
# Episode: 25401 Total Reward: -2009.54 action: [1.6281295] rate_jerk: 10.0000
# EarlyStop Check @Ep25500: AvgReward=-2042.7835
# Episode: 25501 Total Reward: -1908.68 action: [1.7989535] rate_jerk: 10.0000
# EarlyStop Check @Ep25600: AvgReward=-2241.6777
# Episode: 25601 Total Reward: -2003.96 action: [2.017613] rate_jerk: 10.0000
# EarlyStop Check @Ep25700: AvgReward=-1999.8709
# Episode: 25701 Total Reward: -2508.81 action: [2.0670087] rate_jerk: 10.0000
# EarlyStop Check @Ep25800: AvgReward=-2255.6421
# Episode: 25801 Total Reward: -2192.75 action: [1.6627209] rate_jerk: 10.0000
# EarlyStop Check @Ep25900: AvgReward=-2058.1732
# Episode: 25901 Total Reward: -2189.60 action: [1.7985039] rate_jerk: 10.0000
# [Episode 26000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep26000: AvgReward=-2418.4704
# Episode: 26001 Total Reward: -2481.43 action: [1.8892128] rate_jerk: 10.0000
# EarlyStop Check @Ep26100: AvgReward=-2437.1361
# Episode: 26101 Total Reward: -2508.02 action: [1.9900308] rate_jerk: 10.0000
# EarlyStop Check @Ep26200: AvgReward=-2965.7805
# Episode: 26201 Total Reward: -2017.67 action: [1.848032] rate_jerk: 10.0000
# EarlyStop Check @Ep26300: AvgReward=-2129.6502
# Episode: 26301 Total Reward: -2122.48 action: [1.6638519] rate_jerk: 10.0000
# EarlyStop Check @Ep26400: AvgReward=-2044.1676
# Episode: 26401 Total Reward: -2228.69 action: [1.9104966] rate_jerk: 10.0000
# EarlyStop Check @Ep26500: AvgReward=-2334.8357
# Episode: 26501 Total Reward: -2396.50 action: [2.060284] rate_jerk: 10.0000
# EarlyStop Check @Ep26600: AvgReward=-2379.6677
# Episode: 26601 Total Reward: -6871.50 action: [1.7650518] rate_jerk: 10.0000
# EarlyStop Check @Ep26700: AvgReward=-16616.1155
# Episode: 26701 Total Reward: -1516.60 action: [2.054218] rate_jerk: 10.0000
# EarlyStop Check @Ep26800: AvgReward=-1119.1421
# Episode: 26801 Total Reward: -1124.47 action: [1.9950662] rate_jerk: 10.0000
# EarlyStop Check @Ep26900: AvgReward=-1084.5578
# Episode: 26901 Total Reward: -584.88 action: [1.9208219] rate_jerk: 10.0000
# [Episode 27000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep27000: AvgReward=-2991.2994
# Episode: 27001 Total Reward: -2277.94 action: [1.9289834] rate_jerk: 10.0000
# EarlyStop Check @Ep27100: AvgReward=-23892.0955
# Episode: 27101 Total Reward: -2337.57 action: [1.9400938] rate_jerk: 10.0000
# EarlyStop Check @Ep27200: AvgReward=-13608.1313
# Episode: 27201 Total Reward: -21779.97 action: [1.9850776] rate_jerk: 10.0000
# EarlyStop Check @Ep27300: AvgReward=-47223.7195
# Episode: 27301 Total Reward: -1960.99 action: [1.7399111] rate_jerk: 10.0000
# EarlyStop Check @Ep27400: AvgReward=-33867.2441
# Episode: 27401 Total Reward: -168920.35 action: [2.3278546] rate_jerk: 10.0000
# EarlyStop Check @Ep27500: AvgReward=-47022.8638
# Episode: 27501 Total Reward: -1793.36 action: [1.6827048] rate_jerk: 10.0000
# EarlyStop Check @Ep27600: AvgReward=-4372.9127
# Episode: 27601 Total Reward: -9817.98 action: [1.4025233] rate_jerk: 10.0000
# EarlyStop Check @Ep27700: AvgReward=-6982.7756
# Episode: 27701 Total Reward: -18771.45 action: [1.9079217] rate_jerk: 10.0000
# EarlyStop Check @Ep27800: AvgReward=-11094.2452
# Episode: 27801 Total Reward: -28761.21 action: [1.4936916] rate_jerk: 10.0000
# EarlyStop Check @Ep27900: AvgReward=-4971.5858
# Episode: 27901 Total Reward: -1727.08 action: [1.5217116] rate_jerk: 10.0000
# [Episode 28000] Success Rate: 29.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep28000: AvgReward=-4413.8834
# Episode: 28001 Total Reward: -37085.01 action: [1.48001] rate_jerk: 10.0000
# EarlyStop Check @Ep28100: AvgReward=-94564.1010
# Episode: 28101 Total Reward: -88743.46 action: [1.6169606] rate_jerk: 10.0000
# EarlyStop Check @Ep28200: AvgReward=-62271.7775
# Episode: 28201 Total Reward: -2391.53 action: [1.9085045] rate_jerk: 10.0000
# EarlyStop Check @Ep28300: AvgReward=-3893.0530
# Episode: 28301 Total Reward: -8699.63 action: [1.6482205] rate_jerk: 10.0000
# EarlyStop Check @Ep28400: AvgReward=-30590.9727
# Episode: 28401 Total Reward: -60395.24 action: [0.01485348] rate_jerk: 10.0000
# EarlyStop Check @Ep28500: AvgReward=-41597.5839
# Episode: 28501 Total Reward: -732.58 action: [1.2874625] rate_jerk: 10.0000
# EarlyStop Check @Ep28600: AvgReward=-3669.9225
# Episode: 28601 Total Reward: -3488.03 action: [1.7315068] rate_jerk: 10.0000
# EarlyStop Check @Ep28700: AvgReward=-3697.5408
# Episode: 28701 Total Reward: -11210.21 action: [1.7516272] rate_jerk: 10.0000
# EarlyStop Check @Ep28800: AvgReward=-1783.5765
# Episode: 28801 Total Reward: -1743.38 action: [1.7213688] rate_jerk: 10.0000
# EarlyStop Check @Ep28900: AvgReward=-3251.4444
# Episode: 28901 Total Reward: -1275.49 action: [0.08411229] rate_jerk: 10.0000
# [Episode 29000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep29000: AvgReward=-1067.4929
# Episode: 29001 Total Reward: -919.06 action: [1.853472] rate_jerk: 10.0000
# EarlyStop Check @Ep29100: AvgReward=-671.6956
# Episode: 29101 Total Reward: -1587.46 action: [1.9774216] rate_jerk: 10.0000
# EarlyStop Check @Ep29200: AvgReward=-1120.5667
# Episode: 29201 Total Reward: -961.58 action: [2.141147] rate_jerk: 10.0000
# EarlyStop Check @Ep29300: AvgReward=-1373.5727
# Episode: 29301 Total Reward: -1977.39 action: [1.803106] rate_jerk: 10.0000
# EarlyStop Check @Ep29400: AvgReward=-1635.0184
# Episode: 29401 Total Reward: -1521.23 action: [1.8623109] rate_jerk: 10.0000
# EarlyStop Check @Ep29500: AvgReward=-968.1810
# Episode: 29501 Total Reward: -2531.64 action: [1.8380477] rate_jerk: 10.0000
# EarlyStop Check @Ep29600: AvgReward=-1519.6186
# Episode: 29601 Total Reward: -418.05 action: [1.5001097] rate_jerk: 10.0000
# EarlyStop Check @Ep29700: AvgReward=-1773.8436
# Episode: 29701 Total Reward: -2399.94 action: [1.4194247] rate_jerk: 10.0000
# EarlyStop Check @Ep29800: AvgReward=-2067.0781
# Episode: 29801 Total Reward: -2016.39 action: [1.5843556] rate_jerk: 10.0000
# EarlyStop Check @Ep29900: AvgReward=-1615.2607
# Episode: 29901 Total Reward: -104.66 action: [1.6508946] rate_jerk: 10.0000
# [Episode 30000] Success Rate: 9.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep30000: AvgReward=-844.5818
# Episode: 30001 Total Reward: -278.29 action: [1.6435415] rate_jerk: 10.0000
# EarlyStop Check @Ep30100: AvgReward=-1134.3026
# Episode: 30101 Total Reward: -1624.76 action: [1.5306767] rate_jerk: 10.0000
# EarlyStop Check @Ep30200: AvgReward=-1832.0638
# Episode: 30201 Total Reward: -547.78 action: [1.466402] rate_jerk: 10.0000
# EarlyStop Check @Ep30300: AvgReward=-351.0518
# Episode: 30301 Total Reward: -192.19 action: [1.57584] rate_jerk: 10.0000
# EarlyStop Check @Ep30400: AvgReward=-658.1751
# Episode: 30401 Total Reward: -640.48 action: [1.5138993] rate_jerk: 10.0000
# EarlyStop Check @Ep30500: AvgReward=-1162.0295
# Episode: 30501 Total Reward: -385.35 action: [1.6001014] rate_jerk: 10.0000
# EarlyStop Check @Ep30600: AvgReward=-886.3185
# Episode: 30601 Total Reward: -1803.09 action: [1.3714111] rate_jerk: 10.0000
# EarlyStop Check @Ep30700: AvgReward=-12291.7123
# Episode: 30701 Total Reward: -27150.00 action: [0.457137] rate_jerk: 10.0000
# EarlyStop Check @Ep30800: AvgReward=-5630.7283
# Episode: 30801 Total Reward: -3877.97 action: [1.5521] rate_jerk: 10.0000
# EarlyStop Check @Ep30900: AvgReward=-8287.5103
# Episode: 30901 Total Reward: -1711.68 action: [1.5716671] rate_jerk: 10.0000
# [Episode 31000] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep31000: AvgReward=-2045.3768
# Episode: 31001 Total Reward: -2201.34 action: [3.1092532] rate_jerk: 10.0000
# EarlyStop Check @Ep31100: AvgReward=-994.2903
# Episode: 31101 Total Reward: -1339.67 action: [1.4349654] rate_jerk: 10.0000
# EarlyStop Check @Ep31200: AvgReward=-1459.9859
# Episode: 31201 Total Reward: -934.83 action: [1.4037279] rate_jerk: 10.0000
# EarlyStop Check @Ep31300: AvgReward=-7146.8100
# Episode: 31301 Total Reward: -582.40 action: [1.9854925] rate_jerk: 10.0000
# EarlyStop Check @Ep31400: AvgReward=-3015.6260
# Episode: 31401 Total Reward: -963.33 action: [1.7905221] rate_jerk: 10.0000
# EarlyStop Check @Ep31500: AvgReward=-963.3185
# Episode: 31501 Total Reward: -7139.13 action: [1.5528157] rate_jerk: 10.0000
# EarlyStop Check @Ep31600: AvgReward=-1091.3179
# Episode: 31601 Total Reward: -603.94 action: [1.442202] rate_jerk: 10.0000
# EarlyStop Check @Ep31700: AvgReward=-821.7095
# Episode: 31701 Total Reward: -1077.92 action: [1.3098825] rate_jerk: 10.0000
# EarlyStop Check @Ep31800: AvgReward=-2648.2104
# Episode: 31801 Total Reward: -1214.95 action: [1.5162673] rate_jerk: 10.0000
# EarlyStop Check @Ep31900: AvgReward=-986.2227
# Episode: 31901 Total Reward: -968.19 action: [1.6644269] rate_jerk: 10.0000
# [Episode 32000] Success Rate: 7.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep32000: AvgReward=-779.8628
# Episode: 32001 Total Reward: -783.55 action: [1.7753315] rate_jerk: 10.0000
# EarlyStop Check @Ep32100: AvgReward=-1110.9615
# Episode: 32101 Total Reward: -1085.34 action: [1.6017632] rate_jerk: 10.0000
# EarlyStop Check @Ep32200: AvgReward=-1190.6642
# Episode: 32201 Total Reward: -1118.40 action: [2.008731] rate_jerk: 10.0000
# EarlyStop Check @Ep32300: AvgReward=-2569.3928
# Episode: 32301 Total Reward: -517.71 action: [2.1095932] rate_jerk: 10.0000
# EarlyStop Check @Ep32400: AvgReward=-790.4396
# Episode: 32401 Total Reward: -396.40 action: [1.8652225] rate_jerk: 10.0000
# EarlyStop Check @Ep32500: AvgReward=-1111.8309
# Episode: 32501 Total Reward: -1053.26 action: [1.739686] rate_jerk: 10.0000
# EarlyStop Check @Ep32600: AvgReward=-1254.6867
# Episode: 32601 Total Reward: -876.90 action: [1.4507608] rate_jerk: 10.0000
# EarlyStop Check @Ep32700: AvgReward=-1032.4461
# Episode: 32701 Total Reward: -643.35 action: [1.4745668] rate_jerk: 10.0000
# EarlyStop Check @Ep32800: AvgReward=-980.0663
# Episode: 32801 Total Reward: -349.93 action: [1.2177554] rate_jerk: 10.0000
# EarlyStop Check @Ep32900: AvgReward=-1020.0104
# Episode: 32901 Total Reward: -1011.77 action: [1.4342145] rate_jerk: 10.0000
# [Episode 33000] Success Rate: 5.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep33000: AvgReward=-771.7787
# Episode: 33001 Total Reward: -564.85 action: [1.1349776] rate_jerk: 10.0000
# EarlyStop Check @Ep33100: AvgReward=-1366.3870
# Episode: 33101 Total Reward: -2439.56 action: [2.8496742] rate_jerk: 10.0000
# EarlyStop Check @Ep33200: AvgReward=-1443.3838
# Episode: 33201 Total Reward: -1130.51 action: [1.4494357] rate_jerk: 10.0000
# EarlyStop Check @Ep33300: AvgReward=-452.7812
# Episode: 33301 Total Reward: -227.88 action: [1.7341592] rate_jerk: 10.0000
# EarlyStop Check @Ep33400: AvgReward=-1349.2309
# Episode: 33401 Total Reward: -6071.25 action: [2.9569726] rate_jerk: 10.0000
# EarlyStop Check @Ep33500: AvgReward=-1909.1507
# Episode: 33501 Total Reward: -434.51 action: [1.5884103] rate_jerk: 10.0000
# EarlyStop Check @Ep33600: AvgReward=-625.3031
# Episode: 33601 Total Reward: -1301.92 action: [1.6268027] rate_jerk: 10.0000
# EarlyStop Check @Ep33700: AvgReward=-1367.9518
# Episode: 33701 Total Reward: -1440.14 action: [1.5602298] rate_jerk: 10.0000
# EarlyStop Check @Ep33800: AvgReward=-475.3031
# Episode: 33801 Total Reward: -77.38 action: [1.6789387] rate_jerk: 10.0000
# EarlyStop Check @Ep33900: AvgReward=-472.3453
# Episode: 33901 Total Reward: -296.09 action: [1.6747437] rate_jerk: 10.0000
# [Episode 34000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep34000: AvgReward=-746.7732
# Episode: 34001 Total Reward: -756.21 action: [1.7500439] rate_jerk: 10.0000
# EarlyStop Check @Ep34100: AvgReward=-1014.1334
# Episode: 34101 Total Reward: -964.78 action: [1.673273] rate_jerk: 10.0000
# EarlyStop Check @Ep34200: AvgReward=-1585.7234
# Episode: 34201 Total Reward: -1824.19 action: [1.6005836] rate_jerk: 10.0000
# EarlyStop Check @Ep34300: AvgReward=-1382.3939
# Episode: 34301 Total Reward: -212.89 action: [1.2680675] rate_jerk: 10.0000
# EarlyStop Check @Ep34400: AvgReward=-964.4187
# Episode: 34401 Total Reward: -556.29 action: [1.4262974] rate_jerk: 10.0000
# EarlyStop Check @Ep34500: AvgReward=-667.1130
# Episode: 34501 Total Reward: -1311.35 action: [1.7413691] rate_jerk: 10.0000
# EarlyStop Check @Ep34600: AvgReward=-599.9392
# Episode: 34601 Total Reward: -408.13 action: [1.7232748] rate_jerk: 10.0000
# EarlyStop Check @Ep34700: AvgReward=-955.6887
# Episode: 34701 Total Reward: -660.74 action: [1.6558704] rate_jerk: 10.0000
# EarlyStop Check @Ep34800: AvgReward=-1486.2359
# Episode: 34801 Total Reward: -1789.90 action: [2.5965526] rate_jerk: 10.0000
# EarlyStop Check @Ep34900: AvgReward=-746.4600
# Episode: 34901 Total Reward: -769.47 action: [1.7370422] rate_jerk: 10.0000
# [Episode 35000] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep35000: AvgReward=-2721.8447
# Episode: 35001 Total Reward: -4173.14 action: [1.2458991] rate_jerk: 10.0000
# EarlyStop Check @Ep35100: AvgReward=-1691.1841
# Episode: 35101 Total Reward: -101.89 action: [1.7067286] rate_jerk: 10.0000
# EarlyStop Check @Ep35200: AvgReward=-398.6514
# Episode: 35201 Total Reward: -773.25 action: [1.6268198] rate_jerk: 10.0000
# EarlyStop Check @Ep35300: AvgReward=-1896.5233
# Episode: 35301 Total Reward: -2556.90 action: [3.019842] rate_jerk: 10.0000
# EarlyStop Check @Ep35400: AvgReward=-1529.5310
# Episode: 35401 Total Reward: -29.69 action: [1.5501689] rate_jerk: 10.0000
# EarlyStop Check @Ep35500: AvgReward=-1426.6337
# Episode: 35501 Total Reward: -722.27 action: [1.5324965] rate_jerk: 10.0000
# EarlyStop Check @Ep35600: AvgReward=-1490.4217
# Episode: 35601 Total Reward: -113.57 action: [1.7923453] rate_jerk: 10.0000
# EarlyStop Check @Ep35700: AvgReward=-157.8647
# Episode: 35701 Total Reward: -341.15 action: [1.9459817] rate_jerk: 10.0000
# EarlyStop Check @Ep35800: AvgReward=-425.9890
# Episode: 35801 Total Reward: -391.88 action: [1.9557428] rate_jerk: 10.0000
# EarlyStop Check @Ep35900: AvgReward=-188.3987
# Episode: 35901 Total Reward: -216.83 action: [1.9625287] rate_jerk: 10.0000
# [Episode 36000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep36000: AvgReward=-391.5745
# Episode: 36001 Total Reward: -227.87 action: [1.8931574] rate_jerk: 10.0000
# EarlyStop Check @Ep36100: AvgReward=-1317.7957
# Episode: 36101 Total Reward: -2172.74 action: [1.7762194] rate_jerk: 10.0000
# EarlyStop Check @Ep36200: AvgReward=-2314.1283
# Episode: 36201 Total Reward: -2379.35 action: [2.1397405] rate_jerk: 10.0000
# EarlyStop Check @Ep36300: AvgReward=-1242.4289
# Episode: 36301 Total Reward: -300.46 action: [1.848592] rate_jerk: 10.0000
# EarlyStop Check @Ep36400: AvgReward=-585.8365
# Episode: 36401 Total Reward: -1244.57 action: [1.8789036] rate_jerk: 10.0000
# EarlyStop Check @Ep36500: AvgReward=-1305.6505
# Episode: 36501 Total Reward: -2523.81 action: [1.8803927] rate_jerk: 10.0000
# EarlyStop Check @Ep36600: AvgReward=-2178.2215
# Episode: 36601 Total Reward: -2225.06 action: [1.7314155] rate_jerk: 10.0000
# EarlyStop Check @Ep36700: AvgReward=-807.4543
# Episode: 36701 Total Reward: -469.26 action: [1.395311] rate_jerk: 10.0000
# EarlyStop Check @Ep36800: AvgReward=-487.4282
# Episode: 36801 Total Reward: -294.52 action: [1.3412699] rate_jerk: 10.0000
# EarlyStop Check @Ep36900: AvgReward=-302.0688
# Episode: 36901 Total Reward: -468.69 action: [1.7105165] rate_jerk: 10.0000
# [Episode 37000] Success Rate: 14.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep37000: AvgReward=-692.1292
# Episode: 37001 Total Reward: -485.14 action: [2.2997673] rate_jerk: 10.0000
# EarlyStop Check @Ep37100: AvgReward=-274.4099
# Episode: 37101 Total Reward: -384.14 action: [1.8033017] rate_jerk: 10.0000
# EarlyStop Check @Ep37200: AvgReward=-286.6654
# Episode: 37201 Total Reward: -28.67 action: [1.8048537] rate_jerk: 10.0000
# EarlyStop Check @Ep37300: AvgReward=-296.1200
# Episode: 37301 Total Reward: -446.89 action: [1.6809858] rate_jerk: 10.0000
# EarlyStop Check @Ep37400: AvgReward=-217.1170
# Episode: 37401 Total Reward: -430.22 action: [1.5173268] rate_jerk: 10.0000
# EarlyStop Check @Ep37500: AvgReward=-278.7788
# Episode: 37501 Total Reward: -158.38 action: [1.4982246] rate_jerk: 10.0000
# EarlyStop Check @Ep37600: AvgReward=-234.8123
# Episode: 37601 Total Reward: -43.04 action: [1.5302751] rate_jerk: 10.0000
# EarlyStop Check @Ep37700: AvgReward=-133.7508
# Episode: 37701 Total Reward: -274.44 action: [1.2457092] rate_jerk: 10.0000
# EarlyStop Check @Ep37800: AvgReward=-190.3576
# Episode: 37801 Total Reward: -46.35 action: [1.6945021] rate_jerk: 10.0000
# EarlyStop Check @Ep37900: AvgReward=-168.1317
# Episode: 37901 Total Reward: -239.27 action: [1.408814] rate_jerk: 10.0000
# [Episode 38000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep38000: AvgReward=-217.9931
# Episode: 38001 Total Reward: -469.84 action: [0.5033467] rate_jerk: 10.0000
# EarlyStop Check @Ep38100: AvgReward=-259.1645
# Episode: 38101 Total Reward: -157.15 action: [1.3136445] rate_jerk: 10.0000
# EarlyStop Check @Ep38200: AvgReward=-262.0475
# Episode: 38201 Total Reward: -596.59 action: [1.6780556] rate_jerk: 10.0000
# EarlyStop Check @Ep38300: AvgReward=-482.1270
# Episode: 38301 Total Reward: -718.10 action: [1.4556419] rate_jerk: 10.0000
# EarlyStop Check @Ep38400: AvgReward=-226.8631
# Episode: 38401 Total Reward: -168.76 action: [1.6728497] rate_jerk: 10.0000
# EarlyStop Check @Ep38500: AvgReward=-186.4754
# Episode: 38501 Total Reward: -257.15 action: [1.7148746] rate_jerk: 10.0000
# EarlyStop Check @Ep38600: AvgReward=-242.1216
# Episode: 38601 Total Reward: -346.38 action: [1.3560171] rate_jerk: 10.0000
# EarlyStop Check @Ep38700: AvgReward=-519.3550
# Episode: 38701 Total Reward: -527.06 action: [1.3839672] rate_jerk: 10.0000
# EarlyStop Check @Ep38800: AvgReward=-236.2294
# Episode: 38801 Total Reward: -78.17 action: [1.418411] rate_jerk: 10.0000
# EarlyStop Check @Ep38900: AvgReward=-93.6121
# Episode: 38901 Total Reward: -371.82 action: [1.4799669] rate_jerk: 10.0000
# [Episode 39000] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep39000: AvgReward=-171.2811
# Episode: 39001 Total Reward: -357.07 action: [1.5125018] rate_jerk: 10.0000
# EarlyStop Check @Ep39100: AvgReward=-593.0389
# Episode: 39101 Total Reward: -668.38 action: [1.4779414] rate_jerk: 10.0000
# EarlyStop Check @Ep39200: AvgReward=-389.5075
# Episode: 39201 Total Reward: -348.79 action: [1.7701646] rate_jerk: 10.0000
# EarlyStop Check @Ep39300: AvgReward=-231.1567
# Episode: 39301 Total Reward: -177.83 action: [1.3473966] rate_jerk: 10.0000
# EarlyStop Check @Ep39400: AvgReward=-86.8506
# Episode: 39401 Total Reward: -114.62 action: [1.6320189] rate_jerk: 10.0000
# EarlyStop Check @Ep39500: AvgReward=-289.4882
# Episode: 39501 Total Reward: -45.82 action: [1.5130198] rate_jerk: 10.0000
# EarlyStop Check @Ep39600: AvgReward=-71.8130
# Episode: 39601 Total Reward: -28.23 action: [1.8037436] rate_jerk: 10.0000
# EarlyStop Check @Ep39700: AvgReward=-126.1384
# Episode: 39701 Total Reward: -212.13 action: [1.6332929] rate_jerk: 10.0000
# EarlyStop Check @Ep39800: AvgReward=-152.3382
# Episode: 39801 Total Reward: -369.84 action: [1.7525055] rate_jerk: 10.0000
# EarlyStop Check @Ep39900: AvgReward=-172.6767
# Episode: 39901 Total Reward: -87.37 action: [1.6551312] rate_jerk: 10.0000
# [Episode 40000] Success Rate: 49.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep40000: AvgReward=-106.4144
# Episode: 40001 Total Reward: -427.73 action: [1.7988042] rate_jerk: 10.0000
# EarlyStop Check @Ep40100: AvgReward=-548.0375
# Episode: 40101 Total Reward: -347.64 action: [1.3927476] rate_jerk: 10.0000
# EarlyStop Check @Ep40200: AvgReward=-170.4960
# Episode: 40201 Total Reward: -56.85 action: [1.8066599] rate_jerk: 10.0000
# EarlyStop Check @Ep40300: AvgReward=-97.5310
# Episode: 40301 Total Reward: -181.47 action: [1.7646632] rate_jerk: 10.0000
# EarlyStop Check @Ep40400: AvgReward=-100.7947
# Episode: 40401 Total Reward: -120.86 action: [1.7880006] rate_jerk: 10.0000
# EarlyStop Check @Ep40500: AvgReward=-144.5081
# Episode: 40501 Total Reward: -88.02 action: [1.6202753] rate_jerk: 10.0000
# EarlyStop Check @Ep40600: AvgReward=-77.1819
# Episode: 40601 Total Reward: -55.92 action: [1.5847166] rate_jerk: 10.0000
# EarlyStop Check @Ep40700: AvgReward=-247.9310
# Episode: 40701 Total Reward: -59.28 action: [1.7131343] rate_jerk: 10.0000
# EarlyStop Check @Ep40800: AvgReward=-157.2177
# Episode: 40801 Total Reward: -157.08 action: [1.7090421] rate_jerk: 10.0000
# EarlyStop Check @Ep40900: AvgReward=-247.7309
# Episode: 40901 Total Reward: -325.18 action: [1.3827397] rate_jerk: 10.0000
# [Episode 41000] Success Rate: 6.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep41000: AvgReward=-276.9624
# Episode: 41001 Total Reward: -558.93 action: [1.7662731] rate_jerk: 10.0000
# EarlyStop Check @Ep41100: AvgReward=-333.5771
# Episode: 41101 Total Reward: -273.91 action: [1.4791591] rate_jerk: 10.0000
# EarlyStop Check @Ep41200: AvgReward=-377.4509
# Episode: 41201 Total Reward: -1967.34 action: [1.5531937] rate_jerk: 10.0000
# EarlyStop Check @Ep41300: AvgReward=-657.3934
# Episode: 41301 Total Reward: -724.07 action: [1.5637445] rate_jerk: 10.0000
# EarlyStop Check @Ep41400: AvgReward=-253.8254
# Episode: 41401 Total Reward: -479.16 action: [1.7563895] rate_jerk: 10.0000
# EarlyStop Check @Ep41500: AvgReward=-176.3476
# Episode: 41501 Total Reward: -188.79 action: [1.5638956] rate_jerk: 10.0000
# EarlyStop Check @Ep41600: AvgReward=-211.9278
# Episode: 41601 Total Reward: -167.12 action: [1.5874249] rate_jerk: 10.0000
# EarlyStop Check @Ep41700: AvgReward=-116.7498
# Episode: 41701 Total Reward: -195.87 action: [1.597935] rate_jerk: 10.0000
# EarlyStop Check @Ep41800: AvgReward=-192.4540
# Episode: 41801 Total Reward: -297.39 action: [1.6948133] rate_jerk: 10.0000
# EarlyStop Check @Ep41900: AvgReward=-222.0015
# Episode: 41901 Total Reward: -53.27 action: [1.6550632] rate_jerk: 10.0000
# [Episode 42000] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep42000: AvgReward=-159.2961
# Episode: 42001 Total Reward: -391.30 action: [1.5207462] rate_jerk: 10.0000
# EarlyStop Check @Ep42100: AvgReward=-275.7001
# Episode: 42101 Total Reward: -378.00 action: [1.5921632] rate_jerk: 10.0000
# EarlyStop Check @Ep42200: AvgReward=-264.4623
# Episode: 42201 Total Reward: -75.66 action: [1.6967385] rate_jerk: 10.0000
# EarlyStop Check @Ep42300: AvgReward=-334.8903
# Episode: 42301 Total Reward: -210.41 action: [1.5846605] rate_jerk: 10.0000
# EarlyStop Check @Ep42400: AvgReward=-503.3090
# Episode: 42401 Total Reward: -1243.78 action: [1.6126635] rate_jerk: 10.0000
# EarlyStop Check @Ep42500: AvgReward=-464.3372
# Episode: 42501 Total Reward: -42.97 action: [1.4230587] rate_jerk: 10.0000
# EarlyStop Check @Ep42600: AvgReward=-445.3503
# Episode: 42601 Total Reward: -1295.69 action: [1.0976915] rate_jerk: 10.0000
# EarlyStop Check @Ep42700: AvgReward=-530.2800
# Episode: 42701 Total Reward: -328.11 action: [1.5993671] rate_jerk: 10.0000
# EarlyStop Check @Ep42800: AvgReward=-771.9803
# Episode: 42801 Total Reward: -822.09 action: [1.5609512] rate_jerk: 10.0000
# EarlyStop Check @Ep42900: AvgReward=-779.9102
# Episode: 42901 Total Reward: -115.66 action: [1.5560126] rate_jerk: 10.0000
# [Episode 43000] Success Rate: 73.00%
# -> 躍度ペナルティ重みを維持
# EarlyStop Check @Ep43000: AvgReward=-306.0331
# Episode: 43001 Total Reward: -110.85 action: [1.5346773] rate_jerk: 10.0000
# EarlyStop Check @Ep43100: AvgReward=-500.5571
# Episode: 43101 Total Reward: -302.01 action: [1.5971435] rate_jerk: 10.0000
# EarlyStop Check @Ep43200: AvgReward=-189.7909
# Episode: 43201 Total Reward: -101.98 action: [1.7332898] rate_jerk: 10.0000
# EarlyStop Check @Ep43300: AvgReward=-194.5415
# Episode: 43301 Total Reward: -121.54 action: [1.782994] rate_jerk: 10.0000
# EarlyStop Check @Ep43400: AvgReward=-301.3818
# Episode: 43401 Total Reward: -82.03 action: [1.5521281] rate_jerk: 10.0000
# EarlyStop Check @Ep43500: AvgReward=-451.7811
# Episode: 43501 Total Reward: -273.70 action: [1.539345] rate_jerk: 10.0000
# EarlyStop Check @Ep43600: AvgReward=-641.3898
# Episode: 43601 Total Reward: -201.28 action: [1.5457746] rate_jerk: 10.0000
# EarlyStop Check @Ep43700: AvgReward=-408.0791
# Episode: 43701 Total Reward: -949.05 action: [1.6244407] rate_jerk: 10.0000
# EarlyStop Check @Ep43800: AvgReward=-385.3018
# Episode: 43801 Total Reward: -1592.48 action: [1.4960968] rate_jerk: 10.0000
# EarlyStop Check @Ep43900: AvgReward=-876.4672
# Episode: 43901 Total Reward: -667.76 action: [1.6413064] rate_jerk: 10.0000
# [Episode 44000] Success Rate: 7.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep44000: AvgReward=-860.1088
# Episode: 44001 Total Reward: -392.34 action: [1.6920352] rate_jerk: 10.0000
# EarlyStop Check @Ep44100: AvgReward=-757.5984
# Episode: 44101 Total Reward: -726.85 action: [1.5113564] rate_jerk: 10.0000
# EarlyStop Check @Ep44200: AvgReward=-660.6321
# Episode: 44201 Total Reward: -445.04 action: [1.5177442] rate_jerk: 10.0000
# EarlyStop Check @Ep44300: AvgReward=-569.8297
# Episode: 44301 Total Reward: -2800.51 action: [1.7251022] rate_jerk: 10.0000
# EarlyStop Check @Ep44400: AvgReward=-942.9731
# Episode: 44401 Total Reward: -343.63 action: [1.7185612] rate_jerk: 10.0000
# EarlyStop Check @Ep44500: AvgReward=-411.1137
# Episode: 44501 Total Reward: -126.67 action: [1.6877595] rate_jerk: 10.0000
# EarlyStop Check @Ep44600: AvgReward=-727.2124
# Episode: 44601 Total Reward: -235.71 action: [1.5648065] rate_jerk: 10.0000
# EarlyStop Check @Ep44700: AvgReward=-1245.6128
# Episode: 44701 Total Reward: -1663.28 action: [1.6681767] rate_jerk: 10.0000
# EarlyStop Check @Ep44800: AvgReward=-878.3297
# Episode: 44801 Total Reward: -517.88 action: [1.5061808] rate_jerk: 10.0000
# EarlyStop Check @Ep44900: AvgReward=-1180.0713
# Episode: 44901 Total Reward: -919.27 action: [1.3803868] rate_jerk: 10.0000
# [Episode 45000] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep45000: AvgReward=-884.6003
# Episode: 45001 Total Reward: -71.18 action: [1.6881386] rate_jerk: 10.0000
# EarlyStop Check @Ep45100: AvgReward=-1281.6360
# Episode: 45101 Total Reward: -1585.73 action: [1.4474607] rate_jerk: 10.0000
# EarlyStop Check @Ep45200: AvgReward=-1212.1082
# Episode: 45201 Total Reward: -2150.11 action: [1.7582743] rate_jerk: 10.0000
# EarlyStop Check @Ep45300: AvgReward=-1043.2442
# Episode: 45301 Total Reward: -1766.89 action: [1.7247771] rate_jerk: 10.0000
# EarlyStop Check @Ep45400: AvgReward=-964.8132
# Episode: 45401 Total Reward: -1672.60 action: [1.5611933] rate_jerk: 10.0000
# EarlyStop Check @Ep45500: AvgReward=-1168.7914
# ...
# Episode: 273401 Total Reward: -392.37 action: [1.3247839] rate_jerk: 10.0000
# EarlyStop Check @Ep273500: AvgReward=-460.0628
# Episode: 273501 Total Reward: -501.20 action: [1.391288] rate_jerk: 10.0000
# EarlyStop Check @Ep273600: AvgReward=-457.9947
# Episode: 273601 Total Reward: -408.18 action: [1.6349906] rate_jerk: 10.0000
# EarlyStop Check @Ep273700: AvgReward=-374.8071
# Episode: 273701 Total Reward: -584.78 action: [1.4807385] rate_jerk: 10.0000
# EarlyStop Check @Ep273800: AvgReward=-475.0325
# Episode: 273801 Total Reward: -485.60 action: [1.489899] rate_jerk: 10.0000
# EarlyStop Check @Ep273900: AvgReward=-371.8307
# Episode: 273901 Total Reward: -455.74 action: [1.4384358] rate_jerk: 10.0000
# [Episode 274000] Success Rate: 12.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep274000: AvgReward=-477.4938
# Episode: 274001 Total Reward: -594.53 action: [1.3332369] rate_jerk: 10.0000
# EarlyStop Check @Ep274100: AvgReward=-504.8499
# Episode: 274101 Total Reward: -164.08 action: [1.5063696] rate_jerk: 10.0000
# EarlyStop Check @Ep274200: AvgReward=-309.6862
# Episode: 274201 Total Reward: -754.36 action: [1.5043979] rate_jerk: 10.0000
# EarlyStop Check @Ep274300: AvgReward=-587.8753
# Episode: 274301 Total Reward: -519.06 action: [1.4366474] rate_jerk: 10.0000
# EarlyStop Check @Ep274400: AvgReward=-553.8889
# Episode: 274401 Total Reward: -359.55 action: [1.3276851] rate_jerk: 10.0000
# EarlyStop Check @Ep274500: AvgReward=-483.4427
# Episode: 274501 Total Reward: -409.30 action: [1.4617934] rate_jerk: 10.0000
# EarlyStop Check @Ep274600: AvgReward=-585.4999
# Episode: 274601 Total Reward: -425.94 action: [1.477233] rate_jerk: 10.0000
# EarlyStop Check @Ep274700: AvgReward=-303.4066
# Episode: 274701 Total Reward: -522.03 action: [1.5454255] rate_jerk: 10.0000
# EarlyStop Check @Ep274800: AvgReward=-479.0883
# Episode: 274801 Total Reward: -648.92 action: [1.438247] rate_jerk: 10.0000
# EarlyStop Check @Ep274900: AvgReward=-449.4437
# Episode: 274901 Total Reward: -684.94 action: [1.5032096] rate_jerk: 10.0000
# [Episode 275000] Success Rate: 12.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep275000: AvgReward=-205.4184
# Episode: 275001 Total Reward: -208.23 action: [1.4328105] rate_jerk: 10.0000
# EarlyStop Check @Ep275100: AvgReward=-283.2287
# Episode: 275101 Total Reward: -370.42 action: [1.4626355] rate_jerk: 10.0000
# EarlyStop Check @Ep275200: AvgReward=-575.8328
# Episode: 275201 Total Reward: -589.80 action: [1.4997056] rate_jerk: 10.0000
# EarlyStop Check @Ep275300: AvgReward=-438.3657
# Episode: 275301 Total Reward: -71.87 action: [1.4954593] rate_jerk: 10.0000
# EarlyStop Check @Ep275400: AvgReward=-158.4254
# Episode: 275401 Total Reward: -30.32 action: [1.4191607] rate_jerk: 10.0000
# EarlyStop Check @Ep275500: AvgReward=-541.0992
# Episode: 275501 Total Reward: -368.62 action: [1.3955703] rate_jerk: 10.0000
# EarlyStop Check @Ep275600: AvgReward=-682.3081
# Episode: 275601 Total Reward: -290.13 action: [1.325685] rate_jerk: 10.0000
# EarlyStop Check @Ep275700: AvgReward=-644.2282
# Episode: 275701 Total Reward: -857.06 action: [1.3901123] rate_jerk: 10.0000
# EarlyStop Check @Ep275800: AvgReward=-635.4503
# Episode: 275801 Total Reward: -476.50 action: [1.3303629] rate_jerk: 10.0000
# EarlyStop Check @Ep275900: AvgReward=-486.3600
# Episode: 275901 Total Reward: -210.33 action: [1.3781325] rate_jerk: 10.0000
# [Episode 276000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep276000: AvgReward=-182.9196
# Episode: 276001 Total Reward: -195.29 action: [1.4592845] rate_jerk: 10.0000
# EarlyStop Check @Ep276100: AvgReward=-117.2747
# Episode: 276101 Total Reward: -76.78 action: [1.6588614] rate_jerk: 10.0000
# EarlyStop Check @Ep276200: AvgReward=-337.2611
# Episode: 276201 Total Reward: -472.89 action: [1.5623392] rate_jerk: 10.0000
# EarlyStop Check @Ep276300: AvgReward=-300.4415
# Episode: 276301 Total Reward: -112.15 action: [1.5577571] rate_jerk: 10.0000
# EarlyStop Check @Ep276400: AvgReward=-176.6881
# Episode: 276401 Total Reward: -154.30 action: [1.4701675] rate_jerk: 10.0000
# EarlyStop Check @Ep276500: AvgReward=-384.7552
# Episode: 276501 Total Reward: -349.45 action: [1.4755273] rate_jerk: 10.0000
# EarlyStop Check @Ep276600: AvgReward=-761.3337
# Episode: 276601 Total Reward: -498.77 action: [1.4486985] rate_jerk: 10.0000
# EarlyStop Check @Ep276700: AvgReward=-619.7235
# Episode: 276701 Total Reward: -419.95 action: [1.5028262] rate_jerk: 10.0000
# EarlyStop Check @Ep276800: AvgReward=-724.9282
# Episode: 276801 Total Reward: -755.54 action: [1.417299] rate_jerk: 10.0000
# EarlyStop Check @Ep276900: AvgReward=-591.9839
# Episode: 276901 Total Reward: -236.63 action: [1.2589691] rate_jerk: 10.0000
# [Episode 277000] Success Rate: 7.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep277000: AvgReward=-152.1373
# Episode: 277001 Total Reward: -55.19 action: [1.2408824] rate_jerk: 10.0000
# EarlyStop Check @Ep277100: AvgReward=-377.8583
# Episode: 277101 Total Reward: -600.34 action: [1.3748453] rate_jerk: 10.0000
# EarlyStop Check @Ep277200: AvgReward=-626.5781
# Episode: 277201 Total Reward: -392.37 action: [1.2765745] rate_jerk: 10.0000
# EarlyStop Check @Ep277300: AvgReward=-650.3051
# Episode: 277301 Total Reward: -484.97 action: [1.6535462] rate_jerk: 10.0000
# EarlyStop Check @Ep277400: AvgReward=-476.4202
# Episode: 277401 Total Reward: -153.20 action: [1.5015794] rate_jerk: 10.0000
# EarlyStop Check @Ep277500: AvgReward=-302.5754
# Episode: 277501 Total Reward: -343.86 action: [1.4675807] rate_jerk: 10.0000
# EarlyStop Check @Ep277600: AvgReward=-520.2125
# Episode: 277601 Total Reward: -985.45 action: [1.3794165] rate_jerk: 10.0000
# EarlyStop Check @Ep277700: AvgReward=-651.9054
# Episode: 277701 Total Reward: -708.11 action: [1.4951878] rate_jerk: 10.0000
# EarlyStop Check @Ep277800: AvgReward=-427.7322
# Episode: 277801 Total Reward: -116.14 action: [1.2650726] rate_jerk: 10.0000
# EarlyStop Check @Ep277900: AvgReward=-185.0493
# Episode: 277901 Total Reward: -132.16 action: [1.3620911] rate_jerk: 10.0000
# [Episode 278000] Success Rate: 8.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep278000: AvgReward=-139.5042
# Episode: 278001 Total Reward: -128.77 action: [1.2814155] rate_jerk: 10.0000
# EarlyStop Check @Ep278100: AvgReward=-136.3850
# Episode: 278101 Total Reward: -144.58 action: [1.3137295] rate_jerk: 10.0000
# EarlyStop Check @Ep278200: AvgReward=-149.5953
# Episode: 278201 Total Reward: -132.73 action: [1.4398072] rate_jerk: 10.0000
# EarlyStop Check @Ep278300: AvgReward=-126.4615
# Episode: 278301 Total Reward: -87.16 action: [1.5589134] rate_jerk: 10.0000
# EarlyStop Check @Ep278400: AvgReward=-190.7856
# Episode: 278401 Total Reward: -107.81 action: [0.99679416] rate_jerk: 10.0000
# EarlyStop Check @Ep278500: AvgReward=-150.3890
# Episode: 278501 Total Reward: -262.58 action: [0.83339083] rate_jerk: 10.0000
# EarlyStop Check @Ep278600: AvgReward=-248.5759
# Episode: 278601 Total Reward: -108.78 action: [1.199204] rate_jerk: 10.0000
# EarlyStop Check @Ep278700: AvgReward=-185.2813
# Episode: 278701 Total Reward: -257.73 action: [0.9747873] rate_jerk: 10.0000
# EarlyStop Check @Ep278800: AvgReward=-195.1357
# Episode: 278801 Total Reward: -122.67 action: [1.0732489] rate_jerk: 10.0000
# EarlyStop Check @Ep278900: AvgReward=-143.2165
# Episode: 278901 Total Reward: -127.05 action: [0.9236181] rate_jerk: 10.0000
# [Episode 279000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep279000: AvgReward=-151.4355
# Episode: 279001 Total Reward: -226.27 action: [1.0995414] rate_jerk: 10.0000
# EarlyStop Check @Ep279100: AvgReward=-177.0765
# Episode: 279101 Total Reward: -114.10 action: [1.2974147] rate_jerk: 10.0000
# EarlyStop Check @Ep279200: AvgReward=-126.9713
# Episode: 279201 Total Reward: -160.95 action: [1.2559971] rate_jerk: 10.0000
# EarlyStop Check @Ep279300: AvgReward=-175.7684
# Episode: 279301 Total Reward: -300.07 action: [0.97424114] rate_jerk: 10.0000
# EarlyStop Check @Ep279400: AvgReward=-141.9520
# Episode: 279401 Total Reward: -70.26 action: [1.2354275] rate_jerk: 10.0000
# EarlyStop Check @Ep279500: AvgReward=-143.3814
# Episode: 279501 Total Reward: -153.07 action: [1.0868304] rate_jerk: 10.0000
# EarlyStop Check @Ep279600: AvgReward=-160.5244
# Episode: 279601 Total Reward: -87.45 action: [1.2123036] rate_jerk: 10.0000
# EarlyStop Check @Ep279700: AvgReward=-181.4789
# Episode: 279701 Total Reward: -192.32 action: [1.0460615] rate_jerk: 10.0000
# EarlyStop Check @Ep279800: AvgReward=-123.1970
# Episode: 279801 Total Reward: -157.25 action: [1.0376556] rate_jerk: 10.0000
# EarlyStop Check @Ep279900: AvgReward=-116.4501
# Episode: 279901 Total Reward: -137.47 action: [1.0138705] rate_jerk: 10.0000
# [Episode 280000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep280000: AvgReward=-111.0128
# Episode: 280001 Total Reward: -74.73 action: [1.1410341] rate_jerk: 10.0000
# EarlyStop Check @Ep280100: AvgReward=-119.7546
# Episode: 280101 Total Reward: -123.07 action: [1.2149098] rate_jerk: 10.0000
# EarlyStop Check @Ep280200: AvgReward=-144.9480
# Episode: 280201 Total Reward: -86.04 action: [1.2099614] rate_jerk: 10.0000
# EarlyStop Check @Ep280300: AvgReward=-156.3007
# Episode: 280301 Total Reward: -163.97 action: [0.8951883] rate_jerk: 10.0000
# EarlyStop Check @Ep280400: AvgReward=-200.2918
# Episode: 280401 Total Reward: -277.03 action: [0.6068541] rate_jerk: 10.0000
# EarlyStop Check @Ep280500: AvgReward=-179.7586
# Episode: 280501 Total Reward: -126.00 action: [0.9908542] rate_jerk: 10.0000
# EarlyStop Check @Ep280600: AvgReward=-173.6992
# Episode: 280601 Total Reward: -219.37 action: [0.7977887] rate_jerk: 10.0000
# EarlyStop Check @Ep280700: AvgReward=-210.7827
# Episode: 280701 Total Reward: -212.90 action: [0.91637605] rate_jerk: 10.0000
# EarlyStop Check @Ep280800: AvgReward=-342.5386
# Episode: 280801 Total Reward: -475.65 action: [1.032444] rate_jerk: 10.0000
# EarlyStop Check @Ep280900: AvgReward=-279.7948
# Episode: 280901 Total Reward: -138.90 action: [1.1487836] rate_jerk: 10.0000
# [Episode 281000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep281000: AvgReward=-233.8741
# Episode: 281001 Total Reward: -195.48 action: [0.80003756] rate_jerk: 10.0000
# EarlyStop Check @Ep281100: AvgReward=-213.9992
# Episode: 281101 Total Reward: -285.89 action: [0.8555589] rate_jerk: 10.0000
# EarlyStop Check @Ep281200: AvgReward=-200.5023
# Episode: 281201 Total Reward: -351.26 action: [1.0834183] rate_jerk: 10.0000
# EarlyStop Check @Ep281300: AvgReward=-182.7719
# Episode: 281301 Total Reward: -106.39 action: [1.1012876] rate_jerk: 10.0000
# EarlyStop Check @Ep281400: AvgReward=-182.5501
# Episode: 281401 Total Reward: -156.73 action: [1.2568555] rate_jerk: 10.0000
# EarlyStop Check @Ep281500: AvgReward=-514.3558
# Episode: 281501 Total Reward: -627.78 action: [1.1997852] rate_jerk: 10.0000
# EarlyStop Check @Ep281600: AvgReward=-762.2395
# Episode: 281601 Total Reward: -1194.84 action: [0.92063546] rate_jerk: 10.0000
# EarlyStop Check @Ep281700: AvgReward=-4331.8021
# Episode: 281701 Total Reward: -2452.69 action: [1.3998286] rate_jerk: 10.0000
# EarlyStop Check @Ep281800: AvgReward=-1388.7319
# Episode: 281801 Total Reward: -812.65 action: [1.1591146] rate_jerk: 10.0000
# EarlyStop Check @Ep281900: AvgReward=-1061.1711
# Episode: 281901 Total Reward: -646.19 action: [1.2963895] rate_jerk: 10.0000
# [Episode 282000] Success Rate: 6.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep282000: AvgReward=-503.6675
# Episode: 282001 Total Reward: -97.21 action: [1.4001197] rate_jerk: 10.0000
# EarlyStop Check @Ep282100: AvgReward=-233.7611
# Episode: 282101 Total Reward: -94.32 action: [1.4064304] rate_jerk: 10.0000
# EarlyStop Check @Ep282200: AvgReward=-199.4941
# Episode: 282201 Total Reward: -122.11 action: [1.3588369] rate_jerk: 10.0000
# EarlyStop Check @Ep282300: AvgReward=-117.9595
# Episode: 282301 Total Reward: -227.57 action: [1.4683748] rate_jerk: 10.0000
# EarlyStop Check @Ep282400: AvgReward=-107.9894
# Episode: 282401 Total Reward: -114.18 action: [1.4367392] rate_jerk: 10.0000
# EarlyStop Check @Ep282500: AvgReward=-253.5237
# Episode: 282501 Total Reward: -391.43 action: [1.4798596] rate_jerk: 10.0000
# EarlyStop Check @Ep282600: AvgReward=-365.2996
# Episode: 282601 Total Reward: -523.76 action: [1.3932573] rate_jerk: 10.0000
# EarlyStop Check @Ep282700: AvgReward=-453.2551
# Episode: 282701 Total Reward: -2216.94 action: [1.5511706] rate_jerk: 10.0000
# EarlyStop Check @Ep282800: AvgReward=-464.5178
# Episode: 282801 Total Reward: -957.30 action: [1.1415216] rate_jerk: 10.0000
# EarlyStop Check @Ep282900: AvgReward=-509.3739
# Episode: 282901 Total Reward: -264.99 action: [1.3619581] rate_jerk: 10.0000
# [Episode 283000] Success Rate: 9.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep283000: AvgReward=-285.7996
# Episode: 283001 Total Reward: -143.36 action: [1.2886052] rate_jerk: 10.0000
# EarlyStop Check @Ep283100: AvgReward=-159.7248
# Episode: 283101 Total Reward: -100.09 action: [1.5064759] rate_jerk: 10.0000
# EarlyStop Check @Ep283200: AvgReward=-97.6345
# Episode: 283201 Total Reward: -99.81 action: [1.5796151] rate_jerk: 10.0000
# EarlyStop Check @Ep283300: AvgReward=-395.0926
# Episode: 283301 Total Reward: -384.96 action: [1.4823344] rate_jerk: 10.0000
# EarlyStop Check @Ep283400: AvgReward=-455.9474
# Episode: 283401 Total Reward: -496.36 action: [1.1953008] rate_jerk: 10.0000
# EarlyStop Check @Ep283500: AvgReward=-509.0285
# Episode: 283501 Total Reward: -415.87 action: [1.3189625] rate_jerk: 10.0000
# EarlyStop Check @Ep283600: AvgReward=-528.4158
# Episode: 283601 Total Reward: -674.37 action: [0.6171988] rate_jerk: 10.0000
# EarlyStop Check @Ep283700: AvgReward=-641.2055
# Episode: 283701 Total Reward: -745.26 action: [0.3970449] rate_jerk: 10.0000
# EarlyStop Check @Ep283800: AvgReward=-681.5469
# Episode: 283801 Total Reward: -657.56 action: [0.523947] rate_jerk: 10.0000
# EarlyStop Check @Ep283900: AvgReward=-574.5971
# Episode: 283901 Total Reward: -634.87 action: [0.78065383] rate_jerk: 10.0000
# [Episode 284000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep284000: AvgReward=-877.6981
# Episode: 284001 Total Reward: -740.01 action: [0.98113066] rate_jerk: 10.0000
# EarlyStop Check @Ep284100: AvgReward=-830.3199
# Episode: 284101 Total Reward: -856.79 action: [0.6928118] rate_jerk: 10.0000
# EarlyStop Check @Ep284200: AvgReward=-1167.5262
# Episode: 284201 Total Reward: -994.52 action: [0.43473792] rate_jerk: 10.0000
# EarlyStop Check @Ep284300: AvgReward=-1179.0821
# Episode: 284301 Total Reward: -1019.87 action: [1.4085008] rate_jerk: 10.0000
# EarlyStop Check @Ep284400: AvgReward=-397.7073
# Episode: 284401 Total Reward: -255.51 action: [1.5051879] rate_jerk: 10.0000
# EarlyStop Check @Ep284500: AvgReward=-140.2334
# Episode: 284501 Total Reward: -293.85 action: [0.7979026] rate_jerk: 10.0000
# EarlyStop Check @Ep284600: AvgReward=-477.6765
# Episode: 284601 Total Reward: -535.92 action: [0.22500002] rate_jerk: 10.0000
# EarlyStop Check @Ep284700: AvgReward=-135.3919
# Episode: 284701 Total Reward: -64.82 action: [1.5156821] rate_jerk: 10.0000
# EarlyStop Check @Ep284800: AvgReward=-246.4643
# Episode: 284801 Total Reward: -502.49 action: [0.3669877] rate_jerk: 10.0000
# EarlyStop Check @Ep284900: AvgReward=-275.1759
# Episode: 284901 Total Reward: -90.36 action: [1.6234099] rate_jerk: 10.0000
# [Episode 285000] Success Rate: 4.00%
# -> 躍度ペナルティ重みを減少
# EarlyStop Check @Ep285000: AvgReward=-398.4204
# Episode: 285001 Total Reward: -306.10 action: [0.78980464] rate_jerk: 10.0000
# EarlyStop Check @Ep285100: AvgReward=-249.7957
# Episode: 285101 Total Reward: -129.35 action: [1.1472416] rate_jerk: 10.0000
# EarlyStop Check @Ep285200: AvgReward=-310.4575
# Episode: 285201 Total Reward: -323.88 action: [0.66476685] rate_jerk: 10.0000
# EarlyStop Check @Ep285300: AvgReward=-359.5896
# Episode: 285301 Total Reward: -354.30 action: [0.81978464] rate_jerk: 10.0000
# EarlyStop Check @Ep285400: AvgReward=-185.6638
# Episode: 285401 Total Reward: -34.13 action: [1.4834809] rate_jerk: 10.0000
# EarlyStop Check @Ep285500: AvgReward=-277.1751
# Episode: 285501 Total Reward: -171.80 action: [1.0063697] rate_jerk: 10.0000
# EarlyStop Check @Ep285600: AvgReward=-211.6248
# Episode: 285601 Total Reward: -268.48 action: [0.70684975] rate_jerk: 10.0000
# EarlyStop Check @Ep285700: AvgReward=-373.3302
# Episode: 285701 Total Reward: -338.49 action: [0.55579376] rate_jerk: 10.0000

# %%
fig, ax1 = plt.subplots()

ax1.set_xlabel('episode')
ax1.grid()
ax1.plot(history_metrics_y, [m[0] for m in history_metrics], color="C0", marker='.', label="policy_loss")
ax1.legend(loc='upper left')

ax2 = ax1.twinx()
ax2.plot(history_metrics_y, [m[1] for m in history_metrics], color="C1", marker='.', label="q_loss")
ax2.legend(loc='upper right')

fig.tight_layout()  # レイアウトの設定
#plt.savefig('cartp
# ole2.png') # 画像の保存
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       3 ax1.set_xlabel('episode')
#       4 ax1.grid()
# ----> 5 ax1.plot(history_metrics_y, [m[0] for m in history_metrics], color="C0", marker='.', label="policy_loss")
#       6 ax1.legend(loc='upper left')
#       8 ax2 = ax1.twinx()
#
# NameError: name 'history_metrics_y' is not defined

# %%
# 報酬とrate_jerkのリストを抽出
total_rewards = [r["total"] for r in history_rewards]
rate_jerks = [r["rate_jerk"] for r in history_rewards]

# 1000エピソードごとの平均を計算
group_size = 1000
num_groups = len(total_rewards) // group_size
avg_rewards = [np.mean(total_rewards[i * group_size:(i + 1) * group_size]) for i in range(num_groups)]
avg_jerks = [np.mean(rate_jerks[i * group_size:(i + 1) * group_size]) for i in range(num_groups)]
x = np.arange(1, num_groups + 1) * group_size

# プロット
fig, ax1 = plt.subplots(figsize=(10, 5))

color = 'tab:blue'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Average Total Reward (per 1000 episodes)', color=color)
ax1.plot(x, avg_rewards, color=color, label="Average Reward")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # 第2軸（右）
color = 'tab:red'
ax2.set_ylabel('Average Rate Jerk (per 1000 episodes)', color=color)
ax2.plot(x, avg_jerks, color=color, linestyle='--', label="Average Rate Jerk")
ax2.tick_params(axis='y', labelcolor=color)

plt.title("1000エピソードごとの平均報酬とrate_jerk")
fig.tight_layout()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # 報酬とrate_jerkのリストを抽出
# ----> 2 total_rewards = [r["total"] for r in history_rewards]
#       3 rate_jerks = [r["rate_jerk"] for r in history_rewards]
#       5 # 1000エピソードごとの平均を計算
#
# NameError: name 'history_rewards' is not defined
