# %%
import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.keras.optimizers import Adam
from matplotlib import pyplot as plt
from collections import deque
import random
import gym

# シミュレーション条件
EPISODES_MAX = 200000 # エピソード
STEPS_MAX = 30
DT = 0.01  # 時間ステップ
THRESHOLD = 0.03
THRESHOLD_REWARD = - 0.9
GOAL_POS = [0.0, 1.0]
THETA_INIT = 60 # [deg]
STEPS_INIT = 0
WARMUP_EPISODE = 15000
EVAL_INTERVAL = 100
SUCCESS_THRESHOLD_HIGH = 0.8
SUCCESS_THRESHOLD_LOW = 0.5


# 制御対象
L = 1.0  # アームの長さ
THETA_MAX = 180
THETA_MIN = 0


# 強化学習のパラメータ
ACTION_MIN = - 200 # [deg/s]
ACTION_MAX = 200 # [deg/s]
STATE_THETA_MAX = np.pi
STATE_THETA_MIN = 0.0
REWARD_G = 30
REWARD_D = 300
REWARD_P_JE = 0.00000000001
REWARD_JE_LIM = 0.000000001
REWARD_P_V = 5.0
REWARD_P_T = 0.3
REWARD_STD_V = 1.0
REWARD_STD_T = 0.1
REWARD_STD_J = 10
TIME_PUNISH = 0.3
ALPHA = 0.5
BUFFER_SIZE = 1000000 #30000 episodes分
WARMUP_SIZE = 200000
TRAIN_INTARVAL = 10
BATCH_SIZE = 128
SIGMA = 0.9
SOFT_TARGET_TAU = 0.02
HARD_TARGET_INTERVAL = 100
LOG_2PI = tf.constant(np.log(2.0 * np.pi), dtype=tf.float32)


# ニューラルネットワークのパラメータ
GAMMA = 0.99
GAMMA_P = 0.003
GAMMA_V = 0.01
RAYER_INPUT = 3
RAYER_OUTPUT_V = 1
RAYER_OUTPUT_M = 1
RAYER_OUTPUT_S = 1
RAYER_HIDDEN =32

# データ保存
SAVE_INTERVAL = 10000  # 1000エピソードごとに詳細データを保存

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import gym
import numpy as np

class OneJointReachingEnv(gym.Env):
    """1関節アームのリーチング運動環境"""

    def __init__(self):
        super().__init__()

        # シミュレーションパラメータ（外部定義が必要）
        self.dt = DT                          # 時間刻み幅
        self.l = L                            # アームの長さ
        self.max_steps = STEPS_MAX            # 最大ステップ数
        self.goal_threshold = THRESHOLD       # ゴール判定閾値
        self.reward_j = 0          # 躍度ペナルティ重み

        # 状態空間：[角度, 角速度, 経過時間]
        self.observation_space = gym.spaces.Box(
            low=np.array([STATE_THETA_MIN, ACTION_MIN, 0]),
            high=np.array([STATE_THETA_MAX, ACTION_MAX, 1]),
            shape=(3,), dtype=np.float32
        )

        # アクション空間：角速度（ラジアン）
        self.action_space = gym.spaces.Box(
            low=np.radians(ACTION_MIN),
            high=np.radians(ACTION_MAX),
            shape=(1,), dtype=np.float32
        )

        # 目標座標
        self.goal_pos = np.array(GOAL_POS)

        self.reset()

    def set_penalty_weight(self, new_weight):
        """躍度ペナルティの重みを外部から設定"""
        self.reward_j = new_weight

    def reached_goal(self, dist_to_goal):
        """目標まで到達したかを判定"""
        return dist_to_goal <= self.goal_threshold

    def _get_obs(self):
        """現在の観測状態を返す"""
        return np.array([self.theta, self.theta_vel, self.steps / self.max_steps], dtype=np.float32)

    def calicuram(self, episode):
        """カスタム報酬調整用関数（用途に応じて利用）"""
        return (episode / EPISODES_MAX) * 20

    def reset(self):
        """環境のリセット"""
        self.theta = np.radians(THETA_INIT)
        self.steps = STEPS_INIT

        self.theta_vel = 0.0
        self.theta_acc = 0.0
        self.theta_jerk = 0.0

        self.jerk_sum = 0.0
        self.jerk_mem = 0.0
        self.reward_dist = 0.0

        return self._get_obs()

    def step(self, action):
        """1ステップの実行"""

        # 直前の状態を記録
        prev_theta = self.theta
        prev_vel = self.theta_vel
        prev_acc = self.theta_acc

        # 角度の更新（クリッピングあり）
        self.theta += np.clip(action[0], ACTION_MIN, ACTION_MAX) * self.dt
        self.theta = np.clip(self.theta, THETA_MIN, np.radians(THETA_MAX))

        # 動力学の更新（速度・加速度・躍度）
        self.update_dynamics(prev_theta, prev_vel, prev_acc)

        # 躍度の累積
        self.jerk_sum += self.dt * self.theta_jerk ** 2
        self.steps += 1

        # 手先位置と目標までの距離
        hand_pos = self.l * np.array([np.cos(self.theta), np.sin(self.theta)])
        dist_to_goal = np.linalg.norm(hand_pos - self.goal_pos)

        # 報酬内訳
        if self.steps < self.max_steps:
            reward_components = {
                "reward_dist": 0.0,
                "penalty_jerk": 0.0,
                "penalty_vel": 0.0,
                "penalty_time": 0.0,
            }
        else:
            reward_components = {
                "reward_dist": -REWARD_D * dist_to_goal**2,
                "penalty_jerk": -self.reward_j * self.jerk_sum,
                "penalty_vel": -REWARD_P_V * self.theta_vel**2,
                "penalty_time": 0.0
            }

        # 合計報酬
        reward = sum(reward_components.values())

        # 終了条件
        done = self.steps >= self.max_steps

        # デバッグ用情報
        info = {
            "hand_pos": hand_pos,
            "theta_vel": self.theta_vel,
            "theta_acc": self.theta_acc,
            "theta_jerk": self.theta_jerk,
            "dist_to_goal": dist_to_goal,
            "reward_total": reward,
            **reward_components
        }

        return self._get_obs(), reward, done, info

    def update_dynamics(self, prev_theta, prev_vel, prev_acc):
        """関節の運動量（速度・加速度・躍度）の更新"""
        self.theta_vel = (self.theta - prev_theta) / self.dt
        self.theta_acc = (self.theta_vel - prev_vel) / self.dt
        self.theta_jerk = (self.theta_acc - prev_acc) / self.dt

# %%
class PolicyModel(keras.Model):
    """Soft Actor-Critic 用の方策モデル（Squashed Gaussian）"""

    def __init__(self, action_space):
        super().__init__()
        self.action_space = action_space

        # アクション空間のスケーリング情報
        self.action_center = (action_space.high + action_space.low) / 2.0
        self.action_scale = (action_space.high - action_space.low) / 2.0

        # ネットワーク構造（入力3次元：角度・速度・時間）
        self.hidden1 = keras.layers.Dense(RAYER_HIDDEN, activation="relu", input_shape=(3,))
        self.hidden2 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.hidden3 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")

        # 平均と対数標準偏差（出力次元はアクション次元）
        self.mean_layer = keras.layers.Dense(action_space.shape[0], activation="linear")
        self.log_std_layer = keras.layers.Dense(action_space.shape[0], activation="linear")

        # オプティマイザ（学習率は適宜調整）
        self.optimizer = Adam(learning_rate=0.003)

    def call(self, inputs, training=False):
        """平均と標準偏差を出力（正規分布のパラメータ）"""
        x = self.hidden1(inputs)
        x = self.hidden2(x)
        x = self.hidden3(x)

        mean = self.mean_layer(x)
        log_std = tf.clip_by_value(self.log_std_layer(x), -20.0, 2.0)  # 安定化のためクリップ
        stddev = tf.exp(log_std)

        return mean, stddev

    @tf.function
    def sample_actions(self, states, training=False):
        """アクションをサンプル（Squashed Gaussian Policy）"""
        mean, stddev = self(states, training)
        normal_sample = tf.random.normal(mean.shape)

        # 学習時はサンプル、推論時は平均のみ
        raw_action = mean + stddev * normal_sample if training else mean
        squashed_action = tf.tanh(raw_action)  # [-1, 1] に変換

        return squashed_action, mean, stddev, raw_action

    def sample_action(self, states, training=False):
        """環境用にアクションをスケーリングして返す"""
        states = states.reshape(1, -1)
        squashed_action, _, _, _ = self.sample_actions(states, training)
        squashed_action = squashed_action.numpy()[0]

        # 環境用のスケーリング（実アクション空間へ）
        env_action = squashed_action * self.action_scale + self.action_center
        return env_action, squashed_action

# %%
class DualQNetwork(keras.Model):
    def __init__(self):
        super().__init__()

        # Q1ネットワーク（入力: 状態3次元 + アクション1次元 = 4次元）
        self.dense1 = keras.layers.Dense(RAYER_HIDDEN, activation="relu", input_shape=(4,))
        self.dense2 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense3 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense4 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.value1 = keras.layers.Dense(RAYER_HIDDEN, activation="linear")

        # Q2ネットワーク（同様に）
        self.dense5 = keras.layers.Dense(RAYER_HIDDEN, activation="relu", input_shape=(4,))
        self.dense6 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense7 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.dense8 = keras.layers.Dense(RAYER_HIDDEN, activation="relu")
        self.value2 = keras.layers.Dense(RAYER_OUTPUT_V, activation="linear")

        # 最適化手法
        self.optimizer = Adam(learning_rate=0.003)

    def call(self, states, actions, training=False):
        x = tf.concat([states, actions], axis=1)  # shape: (batch, 4)

        # Q1分岐
        x1 = self.dense1(x)
        x1 = self.dense2(x1)
        x1 = self.dense3(x1)
        x1 = self.dense4(x1)
        q1 = self.value1(x1)

        # Q2分岐
        x2 = self.dense5(x)
        x2 = self.dense6(x2)
        x2 = self.dense7(x2)
        x2 = self.dense8(x2)
        q2 = self.value2(x2)

        return q1, q2

# %%
@tf.function
def compute_logpi(mean, stddev, action):
    """通常の正規分布における log π(a|s) を計算"""
    log2pi = tf.constant(np.log(2.0 * np.pi), dtype=tf.float32)#定数を定めるときに用いる
    log_prob = -0.5 * ((action - mean) / stddev) ** 2 \
               - tf.math.log(stddev) \
               - 0.5 * log2pi #logpiをlogにする
    return tf.reduce_sum(log_prob, axis=1, keepdims=True)#actionが多次元で違う確率分布によって出力される場合、logで足し合わせ

# Squashed Gaussian Policy時の logπ(a|s)

@tf.function
def compute_logpi_sgp(mean, stddev, pre_tanh_action):
    """Squashed Gaussian Policy の log π(a|s) を計算"""
    logpi = compute_logpi(mean, stddev, pre_tanh_action)
    # tanhの逆変換でlogπ修正（確率分布が圧縮されているから、それを伸ばす）
    log_det_jacobian = tf.reduce_sum(tf.math.log(1 - tf.tanh(pre_tanh_action) ** 2 + 1e-6), axis=1, keepdims=True)
    return logpi - log_det_jacobian

def update_model(
        policy_model, 
        q_model, 
        target_q_model,
        experiences,
        BATCH_SIZE,
        SIGMA,
        log_alpha,
        log_alpha_optimizer,  # 追加
        soft_target_tau,
        hard_target_interval,
        target_entropy,
        all_train_count,
    ):

    """SACアルゴリズムの1ステップ更新"""
    alpha = tf.math.exp(log_alpha)#何を計算してる？

    # ミニバッチのサンプリング
    batchs = random.sample(experiences, BATCH_SIZE)
    states = np.asarray([e["state"] for e in batchs])
    n_states = np.asarray([e["n_state"] for e in batchs])
    actions = np.asarray([e["action"] for e in batchs])
    rewards = np.asarray([e["reward"] for e in batchs]).reshape((-1, 1))
    dones = np.asarray([e["done"] for e in batchs]).reshape((-1, 1))

    # --- 次状態からアクションとlogπの計算
    n_actions, n_means, n_stddevs, n_action_orgs = policy_model.sample_actions(n_states)
    n_logpi = compute_logpi_sgp(n_means, n_stddevs, n_action_orgs)

    # --- 目標Q値の計算
    n_q1, n_q2 = target_q_model(n_states, n_actions)
    q_vals = rewards + (1 - dones) * GAMMA * tf.minimum(n_q1, n_q2) - (alpha * n_logpi)#logpi(at+1|st+1)になるらしい

    # --- Qモデルの学習
    with tf.GradientTape() as tape:
        q1, q2 = q_model(states, actions, training=True)
        loss1 = tf.reduce_mean(tf.square(q_vals - q1))#2乗してバッチごとに平均
        loss2 = tf.reduce_mean(tf.square(q_vals - q2))
        q_loss = loss1 + loss2#何で和を取るの？

    grads = tape.gradient(q_loss, q_model.trainable_variables)
    q_model.optimizer.apply_gradients(zip(grads, q_model.trainable_variables))

    # --- ポリシーの学習
    with tf.GradientTape() as tape:
        selected_actions, means, stddevs, action_orgs = policy_model.sample_actions(states, training=True)
        logpi = compute_logpi_sgp(means, stddevs, action_orgs)
        q1, q2 = q_model(states, selected_actions)
        q_min = tf.minimum(q1, q2)
        policy_loss = -tf.reduce_mean(q_min - tf.stop_gradient(alpha) * logpi)#バッチ学習を行なっているため個々の損失ではなく、バッチ全体の平均損失について計算

    grads = tape.gradient(policy_loss, policy_model.trainable_variables)#lossの計算に関与したモデルの学習可能変数に対する勾配を求める. policy_model.trainable_variablesはモデル内部の 重みやバイアスなどの学習対象の変数
    policy_model.optimizer.apply_gradients(zip(grads, policy_model.trainable_variables))

    # --- log_alphaの更新
    with tf.GradientTape() as tape:
        entropy_diff = -logpi - target_entropy
        log_alpha_loss = tf.reduce_mean(tf.exp(log_alpha) * entropy_diff)

    grad = tape.gradient(log_alpha_loss, [log_alpha])
    log_alpha_optimizer.apply_gradients(zip(grad, [log_alpha]))

    # --- ソフトターゲット更新
    target_q_model.set_weights([
        (1 - soft_target_tau) * w + soft_target_tau * t 
        for w, t in zip(target_q_model.get_weights(), q_model.get_weights())
    ])

    # --- ハードターゲット同期（一定ステップごと）
    if all_train_count % hard_target_interval == 0:
        target_q_model.set_weights(q_model.get_weights())

    return policy_loss, q_loss

# %%
def train_main():
    # 保存用ディレクトリの作成
    result_dir = "results_5_14"
    os.makedirs(result_dir, exist_ok=True)
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    max_episodes = EPISODES_MAX

    # 早期終了条件の確認
    def check_early_stop(history, episode):
        if episode < 1000:
            return False
        recent = [r["total"] for r in history[-100:]]
        avg_reward = np.mean(recent)
        print(f"EarlyStop Check @Ep{episode}: AvgReward={avg_reward:.4f}")
        return avg_reward > THRESHOLD_REWARD

    # 初期化
    env = OneJointReachingEnv()
    env.set_penalty_weight(0)
    penalty_weight = 0

    target_entropy = -1 * env.observation_space.shape[0]
    policy_model = PolicyModel(env.action_space)
    q_model, target_q_model = DualQNetwork(), DualQNetwork()

    # モデル初期化
    dummy_state = np.random.normal(0, 0.1, size=(1,) + env.observation_space.shape)
    dummy_action = np.random.normal(0, 0.1, size=(1,) + env.action_space.shape)
    q_model(dummy_state, dummy_action)
    target_q_model(dummy_state, dummy_action)
    target_q_model.set_weights(q_model.get_weights())

    log_alpha = tf.Variable(0.0, dtype=tf.float32)
    alpha_optimizer = tf.keras.optimizers.Adam(learning_rate=3e-4)

    # 経験バッファと履歴
    replay_buffer = deque(maxlen=BUFFER_SIZE)
    history_rewards, history_metrics, history_metrics_y, episode_results = [], [], [], []

    total_steps, train_count = 0, 0
    is_last_episode = False

    for episode in range(max_episodes):
        state = np.asarray(env.reset())
        done = False
        total_reward = 0
        step = 0
        metrics_list = []
        success = False

        is_last_episode = (episode == max_episodes - 1)

        # 初期状態記録
        step_data = [f"0 0.00 {L * np.cos(state[0]):.4f} {L * np.sin(state[0]):.4f} {np.degrees(state[0]):.4f} 0.0 0.0 0.0"]
        if is_last_episode:
            step_data_eval = [step_data[0]]

        while not done:
            # 方策に従って行動を選択
            action, pre_tanh = policy_model.sample_action(state, training=not is_last_episode)
            next_state, reward, done, info = env.step(action)
            next_state = np.asarray(next_state)

            # ログ出力
            step += 1
            total_reward += reward
            log_line = (f"{step} {step * DT:.2f} {info['hand_pos'][0]:.4f} {info['hand_pos'][1]:.4f} "
                        f"{np.degrees(next_state[0]):.4f} {np.degrees(info['theta_vel']):.4f} "
                        f"{np.degrees(info['theta_acc']):.4f} {np.degrees(info['theta_jerk']):.4f}")
            step_data.append(log_line)
            if is_last_episode:
                step_data_eval.append(log_line)

            # 学習用データ蓄積と更新
            if not is_last_episode:
                replay_buffer.append({
                    "state": state,
                    "action": pre_tanh,
                    "reward": reward,
                    "n_state": next_state,
                    "done": done,
                })
                if len(replay_buffer) >= WARMUP_SIZE and total_steps % TRAIN_INTARVAL == 0:
                    metrics = update_model(
                        policy_model, q_model, target_q_model,
                        replay_buffer, BATCH_SIZE, SIGMA,
                        log_alpha, alpha_optimizer,
                        soft_target_tau=0.02, hard_target_interval=100,
                        target_entropy=target_entropy,
                        all_train_count=train_count
                    )
                    train_count += 1
                    metrics_list.append(metrics)

            state = next_state
            total_steps += 1

        # ゴール達成判定
        if env.reached_goal(info["dist_to_goal"]):
            success = True
        episode_results.append(success)

        # 報酬履歴の保存
        history_rewards.append({
            "total": total_reward,
            "reward_dist": info.get("reward_dist", 0.0),
            "penalty_jerk": info.get("penalty_jerk", 0.0),
            "penalty_vel": info.get("penalty_vel", 0.0),
            "penalty_time": info.get("penalty_time", 0.0),
        })
        if metrics_list:
            history_metrics.append(np.mean(metrics_list, axis=0))
            history_metrics_y.append(episode)

        # 成功率に基づいたペナルティ調整
        if episode == WARMUP_EPISODE:
            penalty_weight = REWARD_P_JE
            env.set_penalty_weight(penalty_weight)
        
        if episode >= WARMUP_EPISODE and (episode + 1) % EVAL_INTERVAL == 0:
            success_rate = sum(episode_results[-EVAL_INTERVAL:]) / EVAL_INTERVAL
            print(f"[Episode {episode+1}] Success Rate: {success_rate:.2%}")
            if success_rate >= SUCCESS_THRESHOLD_HIGH:
                if penalty_weight <= REWARD_JE_LIM:
                    penalty_weight *= 1.2
                    print(f"-> 躍度ペナルティ重みを増加: {penalty_weight:.5f}")
                else:
                    print("upper-limit")
            elif success_rate <= SUCCESS_THRESHOLD_LOW:
                penalty_weight *= 0.8
                print(f"-> 躍度ペナルティ重みを減少: {penalty_weight:.5f}")
            env.set_penalty_weight(penalty_weight)

        # ログファイル保存
        if (episode + 1) % SAVE_INTERVAL == 0:
            with open(f"{result_dir}/{timestamp}_data_{episode+1}.csv", "w") as f:
                f.write("Step Time HandX HandY Theta Theta_vel Theta_ac Theta_je\n")
                f.write("\n".join(step_data))

        if is_last_episode:
            with open(f"{result_dir}/{timestamp}_eval_last_episode.csv", "w") as f:
                f.write("Step Time HandX HandY Theta Theta_vel Theta_ac Theta_je\n")
                f.write("\n".join(step_data_eval))

        if episode % 100 == 0:
            print(f"Episode: {episode+1}, Total Reward: {total_reward:.2f} action: {action}")

        # 早期終了条件チェック
        if (episode + 1) % 100 == 0 and penalty_weight >= REWARD_JE_LIM:
            if check_early_stop(history_rewards, episode + 1):
                print(f"✅ 準最適方策を獲得: Ep{episode+1}で学習終了")
                max_episodes = episode + 2

    # 報酬履歴の保存
    with open(f"{result_dir}/{timestamp}_data_sum.csv", "w") as f:
        f.write("Episode TotalReward RewardDist PenaltyJerk PenaltyVel PenaltyTime\n")
        for i, r in enumerate(history_rewards):
            f.write(f"{i+1} {r['total']:.4f} {r['reward_dist']:.4f} "
                    f"{r['penalty_jerk']:.4f} {r['penalty_vel']:.4f} {r['penalty_time']:.4f}\n")

    print("データの保存が完了しました！")
    return policy_model, history_rewards, history_metrics, history_metrics_y

# %%
model, history_rewards21, history_metrics, history_metrics_y = train_main()
# Out:
# Episode: 1, Total Reward: -185.72 action: [-1.8692651]
# Episode: 101, Total Reward: -63.60 action: [-1.6800656]
# Episode: 201, Total Reward: -162.69 action: [-2.419054]
# Episode: 301, Total Reward: -115.71 action: [-1.2560438]
# Episode: 401, Total Reward: -196.37 action: [2.6281521]
# Episode: 501, Total Reward: -172.85 action: [-1.8062961]
# Episode: 601, Total Reward: -81.37 action: [-1.7888921]
# Episode: 701, Total Reward: -164.55 action: [-1.9379126]
# Episode: 801, Total Reward: -144.09 action: [3.2850356]
# Episode: 901, Total Reward: -149.68 action: [-2.4566607]
# Episode: 1001, Total Reward: -120.25 action: [0.213348]
# Episode: 1101, Total Reward: -65.16 action: [-0.40662718]
# Episode: 1201, Total Reward: -69.54 action: [1.2470727]
# Episode: 1301, Total Reward: -154.01 action: [-2.3294249]
# Episode: 1401, Total Reward: -117.66 action: [-0.81762487]
# Episode: 1501, Total Reward: -142.31 action: [-3.1306815]
# Episode: 1601, Total Reward: -84.36 action: [0.19054416]
# Episode: 1701, Total Reward: -74.57 action: [2.1207817]
# Episode: 1801, Total Reward: -39.12 action: [-0.03265814]
# Episode: 1901, Total Reward: -87.14 action: [-1.7824156]
# Episode: 2001, Total Reward: -93.93 action: [0.8580149]
# Episode: 2101, Total Reward: -89.28 action: [1.5108397]
# Episode: 2201, Total Reward: -138.01 action: [0.5978082]
# Episode: 2301, Total Reward: -169.54 action: [-3.2953088]
# Episode: 2401, Total Reward: -117.99 action: [-0.730428]
# Episode: 2501, Total Reward: -133.78 action: [1.8720046]
# Episode: 2601, Total Reward: -131.09 action: [-1.9209155]
# Episode: 2701, Total Reward: -69.75 action: [1.444725]
# Episode: 2801, Total Reward: -104.25 action: [3.0441744]
# Episode: 2901, Total Reward: -138.78 action: [-1.8140777]
# Episode: 3001, Total Reward: -94.65 action: [2.7472405]
# Episode: 3101, Total Reward: -128.19 action: [-2.5148864]
# Episode: 3201, Total Reward: -106.23 action: [-0.1234685]
# Episode: 3301, Total Reward: -107.46 action: [-1.96992]
# Episode: 3401, Total Reward: -174.94 action: [-3.2540643]
# Episode: 3501, Total Reward: -81.73 action: [2.0692692]
# Episode: 3601, Total Reward: -95.56 action: [-0.167644]
# Episode: 3701, Total Reward: -137.10 action: [2.2326336]
# Episode: 3801, Total Reward: -160.99 action: [-3.3261626]
# Episode: 3901, Total Reward: -74.26 action: [2.157013]
# Episode: 4001, Total Reward: -125.41 action: [-1.1052299]
# Episode: 4101, Total Reward: -99.54 action: [-0.09432411]
# Episode: 4201, Total Reward: -48.61 action: [-1.3249915]
# Episode: 4301, Total Reward: -121.53 action: [1.976123]
# Episode: 4401, Total Reward: -72.70 action: [1.0266718]
# Episode: 4501, Total Reward: -123.35 action: [-1.8971986]
# Episode: 4601, Total Reward: -141.40 action: [3.4401624]
# Episode: 4701, Total Reward: -164.54 action: [3.004496]
# Episode: 4801, Total Reward: -118.88 action: [2.4098613]
# Episode: 4901, Total Reward: -76.05 action: [0.00258545]
# Episode: 5001, Total Reward: -104.43 action: [-2.1795948]
# Episode: 5101, Total Reward: -91.62 action: [1.7320244]
# Episode: 5201, Total Reward: -130.51 action: [1.233447]
# Episode: 5301, Total Reward: -50.94 action: [-0.68184316]
# Episode: 5401, Total Reward: -141.94 action: [2.2773452]
# Episode: 5501, Total Reward: -124.36 action: [-1.3197144]
# Episode: 5601, Total Reward: -44.10 action: [0.6816049]
# Episode: 5701, Total Reward: -184.89 action: [-1.5494598]
# Episode: 5801, Total Reward: -136.77 action: [-2.823279]
# Episode: 5901, Total Reward: -142.03 action: [-0.744634]
# Episode: 6001, Total Reward: -79.17 action: [2.527164]
# Episode: 6101, Total Reward: -117.48 action: [0.6531302]
# Episode: 6201, Total Reward: -74.22 action: [1.9222953]
# Episode: 6301, Total Reward: -82.15 action: [-1.6658258]
# Episode: 6401, Total Reward: -135.12 action: [1.4406272]
# Episode: 6501, Total Reward: -106.40 action: [-2.560287]
# Episode: 6601, Total Reward: -168.23 action: [-2.2994356]
# Episode: 6701, Total Reward: -57.28 action: [3.1997807]
# Episode: 6801, Total Reward: -44.79 action: [2.8771682]
# Episode: 6901, Total Reward: -20.75 action: [1.0490296]
# Episode: 7001, Total Reward: -51.73 action: [2.3914533]
# Episode: 7101, Total Reward: -12.47 action: [0.02174443]
# Episode: 7201, Total Reward: -41.44 action: [1.7916502]
# Episode: 7301, Total Reward: -47.78 action: [0.2351921]
# Episode: 7401, Total Reward: -63.44 action: [1.8572602]
# Episode: 7501, Total Reward: -42.84 action: [1.5642825]
# Episode: 7601, Total Reward: -31.62 action: [2.5146008]
# Episode: 7701, Total Reward: -33.77 action: [2.5837722]
# Episode: 7801, Total Reward: -52.32 action: [3.200323]
# Episode: 7901, Total Reward: -25.43 action: [2.1973467]
# Episode: 8001, Total Reward: -10.59 action: [1.3039526]
# Episode: 8101, Total Reward: -11.65 action: [1.2980587]
# Episode: 8201, Total Reward: -20.49 action: [1.9603872]
# Episode: 8301, Total Reward: -4.70 action: [0.9084912]
# Episode: 8401, Total Reward: -12.87 action: [1.4776546]
# Episode: 8501, Total Reward: -36.94 action: [2.6630664]
# Episode: 8601, Total Reward: -18.72 action: [1.534214]
# Episode: 8701, Total Reward: -26.78 action: [2.2715943]
# Episode: 8801, Total Reward: -9.02 action: [0.83240044]
# Episode: 8901, Total Reward: -9.10 action: [1.2507055]
# Episode: 9001, Total Reward: -8.73 action: [1.3196341]
# Episode: 9101, Total Reward: -4.40 action: [0.7917657]
# Episode: 9201, Total Reward: -6.81 action: [0.8093988]
# Episode: 9301, Total Reward: -7.10 action: [1.0955032]
# Episode: 9401, Total Reward: -9.78 action: [0.8860594]
# Episode: 9501, Total Reward: -10.62 action: [0.6387081]
# Episode: 9601, Total Reward: -11.02 action: [0.7387916]
# Episode: 9701, Total Reward: -11.24 action: [0.7414921]
# Episode: 9801, Total Reward: -9.21 action: [0.5464162]
# Episode: 9901, Total Reward: -9.28 action: [0.5520819]
# Episode: 10001, Total Reward: -8.94 action: [0.56042516]
# Episode: 10101, Total Reward: -6.80 action: [0.6319663]
# Episode: 10201, Total Reward: -13.35 action: [0.8722136]
# Episode: 10301, Total Reward: -9.36 action: [0.9031591]
# Episode: 10401, Total Reward: -5.84 action: [0.6861618]
# Episode: 10501, Total Reward: -9.63 action: [0.7922413]
# Episode: 10601, Total Reward: -6.97 action: [0.6727784]
# Episode: 10701, Total Reward: -7.13 action: [0.71067065]
# Episode: 10801, Total Reward: -8.76 action: [1.0242265]
# Episode: 10901, Total Reward: -4.61 action: [0.1904082]
# Episode: 11001, Total Reward: -9.82 action: [0.5927408]
# Episode: 11101, Total Reward: -7.19 action: [0.5620277]
# Episode: 11201, Total Reward: -3.92 action: [0.62138957]
# Episode: 11301, Total Reward: -6.47 action: [0.22522344]
# Episode: 11401, Total Reward: -3.28 action: [0.38838574]
# Episode: 11501, Total Reward: -5.18 action: [0.39675182]
# Episode: 11601, Total Reward: -5.38 action: [-0.08075914]
# Episode: 11701, Total Reward: -4.76 action: [-0.13077447]
# Episode: 11801, Total Reward: -7.25 action: [0.02114935]
# Episode: 11901, Total Reward: -3.85 action: [0.3912909]
# Episode: 12001, Total Reward: -3.92 action: [0.09597123]
# Episode: 12101, Total Reward: -2.48 action: [0.23959729]
# Episode: 12201, Total Reward: -1.64 action: [0.42441684]
# Episode: 12301, Total Reward: -1.93 action: [-0.0666998]
# Episode: 12401, Total Reward: -7.92 action: [0.68962616]
# Episode: 12501, Total Reward: -2.89 action: [0.31643257]
# Episode: 12601, Total Reward: -3.79 action: [0.3769436]
# Episode: 12701, Total Reward: -1.17 action: [0.11884839]
# Episode: 12801, Total Reward: -2.57 action: [0.06557094]
# Episode: 12901, Total Reward: -1.26 action: [0.10727812]
# Episode: 13001, Total Reward: -3.91 action: [0.20435977]
# Episode: 13101, Total Reward: -5.73 action: [0.3036808]
# Episode: 13201, Total Reward: -7.86 action: [0.46527338]
# Episode: 13301, Total Reward: -1.04 action: [0.37255707]
# Episode: 13401, Total Reward: -2.22 action: [0.13267192]
# Episode: 13501, Total Reward: -0.03 action: [0.04915391]
# Episode: 13601, Total Reward: -0.76 action: [0.30118838]
# Episode: 13701, Total Reward: -0.91 action: [0.33305547]
# Episode: 13801, Total Reward: -1.43 action: [0.15286838]
# Episode: 13901, Total Reward: -0.04 action: [0.07350097]
# Episode: 14001, Total Reward: -2.32 action: [-0.11325926]
# Episode: 14101, Total Reward: -3.56 action: [0.2841016]
# Episode: 14201, Total Reward: -3.09 action: [0.36796546]
# Episode: 14301, Total Reward: -1.56 action: [0.24869893]
# Episode: 14401, Total Reward: -1.26 action: [0.50131106]
# Episode: 14501, Total Reward: -0.38 action: [0.2459649]
# Episode: 14601, Total Reward: -0.28 action: [0.23103768]
# Episode: 14701, Total Reward: -0.98 action: [-0.3233446]
# Episode: 14801, Total Reward: -1.12 action: [0.45744988]
# Episode: 14901, Total Reward: -3.79 action: [0.55112195]
# Episode: 15001, Total Reward: -3.58 action: [0.46042988]
# [Episode 15100] Success Rate: 41.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15101, Total Reward: -1.69 action: [0.5710109]
# [Episode 15200] Success Rate: 1.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15201, Total Reward: -2.95 action: [0.6535538]
# [Episode 15300] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15301, Total Reward: -4.05 action: [0.4867488]
# [Episode 15400] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15401, Total Reward: -2.46 action: [0.6569899]
# [Episode 15500] Success Rate: 17.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15501, Total Reward: -1.55 action: [0.5044331]
# [Episode 15600] Success Rate: 35.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15601, Total Reward: -1.45 action: [0.49684975]
# [Episode 15700] Success Rate: 17.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15701, Total Reward: -1.76 action: [0.32115436]
# [Episode 15800] Success Rate: 14.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15801, Total Reward: -0.25 action: [0.21016388]
# [Episode 15900] Success Rate: 29.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 15901, Total Reward: -4.20 action: [0.4714794]
# [Episode 16000] Success Rate: 14.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 16001, Total Reward: -1.07 action: [0.27911994]
# [Episode 16100] Success Rate: 41.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 16101, Total Reward: -2.14 action: [0.42247203]
# [Episode 16200] Success Rate: 54.00%
# Episode: 16201, Total Reward: -0.25 action: [0.16944054]
# [Episode 16300] Success Rate: 64.00%
# Episode: 16301, Total Reward: -1.28 action: [0.35288027]
# [Episode 16400] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 16401, Total Reward: -1.87 action: [0.44803125]
# [Episode 16500] Success Rate: 57.00%
# Episode: 16501, Total Reward: -0.79 action: [0.38473612]
# [Episode 16600] Success Rate: 73.00%
# Episode: 16601, Total Reward: -0.98 action: [0.42524007]
# [Episode 16700] Success Rate: 38.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 16701, Total Reward: -0.83 action: [0.37763608]
# [Episode 16800] Success Rate: 77.00%
# Episode: 16801, Total Reward: -0.24 action: [-0.03231309]
# [Episode 16900] Success Rate: 53.00%
# Episode: 16901, Total Reward: -0.62 action: [0.30736652]
# [Episode 17000] Success Rate: 50.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17001, Total Reward: -2.34 action: [0.15390679]
# [Episode 17100] Success Rate: 20.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17101, Total Reward: -2.00 action: [0.23461282]
# [Episode 17200] Success Rate: 23.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17201, Total Reward: -3.19 action: [-0.04295982]
# [Episode 17300] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17301, Total Reward: -15.16 action: [-1.493155]
# [Episode 17400] Success Rate: 11.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17401, Total Reward: -0.36 action: [0.13895063]
# [Episode 17500] Success Rate: 22.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17501, Total Reward: -0.58 action: [0.27661392]
# [Episode 17600] Success Rate: 17.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17601, Total Reward: -7.61 action: [-0.6993268]
# [Episode 17700] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17701, Total Reward: -0.94 action: [0.42112797]
# [Episode 17800] Success Rate: 37.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17801, Total Reward: -0.70 action: [0.08560018]
# [Episode 17900] Success Rate: 23.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 17901, Total Reward: -0.57 action: [-0.02560403]
# [Episode 18000] Success Rate: 18.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18001, Total Reward: -11.11 action: [-1.2687542]
# [Episode 18100] Success Rate: 23.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18101, Total Reward: -0.21 action: [-0.19927631]
# [Episode 18200] Success Rate: 79.00%
# Episode: 18201, Total Reward: -0.10 action: [0.0610569]
# [Episode 18300] Success Rate: 24.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18301, Total Reward: -4.96 action: [-0.46609184]
# [Episode 18400] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18401, Total Reward: -10.32 action: [-1.433143]
# [Episode 18500] Success Rate: 35.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18501, Total Reward: -0.69 action: [0.05587416]
# [Episode 18600] Success Rate: 43.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18601, Total Reward: -1.83 action: [0.59091777]
# [Episode 18700] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18701, Total Reward: -0.22 action: [-0.2098058]
# [Episode 18800] Success Rate: 38.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18801, Total Reward: -0.30 action: [0.24072698]
# [Episode 18900] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 18901, Total Reward: -11.34 action: [-1.1257313]
# [Episode 19000] Success Rate: 12.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19001, Total Reward: -20.10 action: [-1.9894081]
# [Episode 19100] Success Rate: 36.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19101, Total Reward: -3.69 action: [0.52422917]
# [Episode 19200] Success Rate: 47.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19201, Total Reward: -1.67 action: [0.38814664]
# [Episode 19300] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19301, Total Reward: -2.75 action: [0.22983192]
# [Episode 19400] Success Rate: 16.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19401, Total Reward: -1.94 action: [0.19465706]
# [Episode 19500] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19501, Total Reward: -9.96 action: [0.6486308]
# [Episode 19600] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19601, Total Reward: -3.32 action: [0.02264833]
# [Episode 19700] Success Rate: 52.00%
# Episode: 19701, Total Reward: -0.53 action: [-0.25558847]
# [Episode 19800] Success Rate: 36.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19801, Total Reward: -0.65 action: [-0.27382705]
# [Episode 19900] Success Rate: 2.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 19901, Total Reward: -8.25 action: [0.33997172]
# [Episode 20000] Success Rate: 35.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20001, Total Reward: -4.46 action: [0.4135008]
# [Episode 20100] Success Rate: 40.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20101, Total Reward: -1.28 action: [0.18886496]
# [Episode 20200] Success Rate: 16.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20201, Total Reward: -0.01 action: [0.04002532]
# [Episode 20300] Success Rate: 36.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20301, Total Reward: -0.12 action: [0.07674013]
# [Episode 20400] Success Rate: 5.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20401, Total Reward: -1.68 action: [0.23441292]
# [Episode 20500] Success Rate: 21.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20501, Total Reward: -0.24 action: [0.0898006]
# [Episode 20600] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20601, Total Reward: -1.52 action: [-0.2359334]
# [Episode 20700] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20701, Total Reward: -0.15 action: [-0.02159558]
# [Episode 20800] Success Rate: 20.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20801, Total Reward: -6.07 action: [0.14932002]
# [Episode 20900] Success Rate: 34.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 20901, Total Reward: -6.61 action: [-1.1107754]
# [Episode 21000] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21001, Total Reward: -0.75 action: [0.2234834]
# [Episode 21100] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21101, Total Reward: -0.62 action: [0.3466914]
# [Episode 21200] Success Rate: 17.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21201, Total Reward: -0.82 action: [-0.228125]
# [Episode 21300] Success Rate: 31.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21301, Total Reward: -0.72 action: [-0.33590105]
# [Episode 21400] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21401, Total Reward: -6.27 action: [-0.51177335]
# [Episode 21500] Success Rate: 8.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21501, Total Reward: -1.53 action: [0.29336]
# [Episode 21600] Success Rate: 18.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21601, Total Reward: -1.07 action: [0.4107217]
# [Episode 21700] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21701, Total Reward: -1.73 action: [0.39059404]
# [Episode 21800] Success Rate: 53.00%
# Episode: 21801, Total Reward: -0.66 action: [0.17758678]
# [Episode 21900] Success Rate: 43.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 21901, Total Reward: -3.34 action: [0.5242638]
# [Episode 22000] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22001, Total Reward: -4.15 action: [0.23756346]
# [Episode 22100] Success Rate: 49.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22101, Total Reward: -1.51 action: [-0.22520848]
# [Episode 22200] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22201, Total Reward: -6.55 action: [0.21483591]
# [Episode 22300] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22301, Total Reward: -12.76 action: [0.14156608]
# [Episode 22400] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22401, Total Reward: -1.73 action: [-0.58590305]
# [Episode 22500] Success Rate: 5.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22501, Total Reward: -6.64 action: [-0.4731009]
# [Episode 22600] Success Rate: 19.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 22601, Total Reward: -0.62 action: [0.29688188]
# [Episode 22700] Success Rate: 59.00%
# Episode: 22701, Total Reward: -0.55 action: [0.33018652]
# [Episode 22800] Success Rate: 59.00%
# Episode: 22801, Total Reward: -0.72 action: [-0.06791946]
# [Episode 22900] Success Rate: 54.00%
# Episode: 22901, Total Reward: -0.30 action: [-0.2416041]
# [Episode 23000] Success Rate: 29.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23001, Total Reward: -0.84 action: [-0.32269537]
# [Episode 23100] Success Rate: 31.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23101, Total Reward: -4.76 action: [0.04290927]
# [Episode 23200] Success Rate: 16.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23201, Total Reward: -1.37 action: [-0.09016512]
# [Episode 23300] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23301, Total Reward: -1.96 action: [0.27834255]
# [Episode 23400] Success Rate: 16.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23401, Total Reward: -1.27 action: [-0.14013739]
# [Episode 23500] Success Rate: 78.00%
# Episode: 23501, Total Reward: -0.19 action: [0.17617053]
# [Episode 23600] Success Rate: 45.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23601, Total Reward: -0.46 action: [0.06865864]
# [Episode 23700] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23701, Total Reward: -3.79 action: [-0.29880375]
# [Episode 23800] Success Rate: 11.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23801, Total Reward: -0.65 action: [0.05030082]
# [Episode 23900] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 23901, Total Reward: -0.98 action: [-0.42605835]
# [Episode 24000] Success Rate: 52.00%
# Episode: 24001, Total Reward: -4.67 action: [-0.0005711]
# [Episode 24100] Success Rate: 24.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24101, Total Reward: -1.59 action: [-0.34529823]
# [Episode 24200] Success Rate: 34.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24201, Total Reward: -0.93 action: [0.2571283]
# [Episode 24300] Success Rate: 66.00%
# Episode: 24301, Total Reward: -0.09 action: [0.04563824]
# [Episode 24400] Success Rate: 55.00%
# Episode: 24401, Total Reward: -1.06 action: [-0.18108]
# [Episode 24500] Success Rate: 49.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24501, Total Reward: -1.53 action: [-0.03507483]
# [Episode 24600] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24601, Total Reward: -0.57 action: [-0.00677096]
# [Episode 24700] Success Rate: 19.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24701, Total Reward: -3.16 action: [-0.01892222]
# [Episode 24800] Success Rate: 4.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24801, Total Reward: -1.01 action: [-0.04496319]
# [Episode 24900] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 24901, Total Reward: -1.43 action: [-0.0675223]
# [Episode 25000] Success Rate: 44.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25001, Total Reward: -0.39 action: [-0.19556348]
# [Episode 25100] Success Rate: 22.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25101, Total Reward: -0.30 action: [0.12645897]
# [Episode 25200] Success Rate: 23.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25201, Total Reward: -2.13 action: [0.0024502]
# [Episode 25300] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25301, Total Reward: -5.59 action: [0.10456728]
# [Episode 25400] Success Rate: 18.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25401, Total Reward: -0.35 action: [-0.2566477]
# [Episode 25500] Success Rate: 55.00%
# Episode: 25501, Total Reward: -0.38 action: [0.0869658]
# [Episode 25600] Success Rate: 31.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25601, Total Reward: -2.35 action: [0.25369534]
# [Episode 25700] Success Rate: 14.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25701, Total Reward: -2.60 action: [-0.1200567]
# [Episode 25800] Success Rate: 43.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25801, Total Reward: -0.97 action: [0.29333544]
# [Episode 25900] Success Rate: 18.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 25901, Total Reward: -1.81 action: [0.22142504]
# [Episode 26000] Success Rate: 8.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26001, Total Reward: -2.51 action: [0.2775595]
# [Episode 26100] Success Rate: 29.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26101, Total Reward: -0.22 action: [0.2084825]
# [Episode 26200] Success Rate: 22.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26201, Total Reward: -1.81 action: [0.39996502]
# [Episode 26300] Success Rate: 25.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26301, Total Reward: -0.84 action: [0.26710013]
# [Episode 26400] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26401, Total Reward: -0.96 action: [0.32278305]
# [Episode 26500] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26501, Total Reward: -0.71 action: [0.2419905]
# [Episode 26600] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26601, Total Reward: -0.78 action: [0.18890053]
# [Episode 26700] Success Rate: 43.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26701, Total Reward: -0.16 action: [0.09921747]
# [Episode 26800] Success Rate: 40.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26801, Total Reward: -0.21 action: [-0.01875833]
# [Episode 26900] Success Rate: 38.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 26901, Total Reward: -1.34 action: [0.2957255]
# [Episode 27000] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27001, Total Reward: -0.17 action: [0.08460043]
# [Episode 27100] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27101, Total Reward: -0.04 action: [0.06592628]
# [Episode 27200] Success Rate: 51.00%
# Episode: 27201, Total Reward: -0.18 action: [0.17199509]
# [Episode 27300] Success Rate: 70.00%
# Episode: 27301, Total Reward: -0.67 action: [0.08021731]
# [Episode 27400] Success Rate: 36.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27401, Total Reward: -1.23 action: [0.31979188]
# [Episode 27500] Success Rate: 34.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27501, Total Reward: -0.39 action: [0.2644731]
# [Episode 27600] Success Rate: 42.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27601, Total Reward: -1.70 action: [0.49521783]
# [Episode 27700] Success Rate: 25.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27701, Total Reward: -1.63 action: [0.4102034]
# [Episode 27800] Success Rate: 51.00%
# Episode: 27801, Total Reward: -0.33 action: [0.21529357]
# [Episode 27900] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 27901, Total Reward: -1.00 action: [0.07802456]
# [Episode 28000] Success Rate: 19.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28001, Total Reward: -1.34 action: [0.34587836]
# [Episode 28100] Success Rate: 44.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28101, Total Reward: -0.61 action: [0.27373347]
# [Episode 28200] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28201, Total Reward: -1.12 action: [0.21009147]
# [Episode 28300] Success Rate: 49.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28301, Total Reward: -0.52 action: [0.20603116]
# [Episode 28400] Success Rate: 46.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28401, Total Reward: -0.43 action: [0.2629981]
# [Episode 28500] Success Rate: 65.00%
# Episode: 28501, Total Reward: -0.44 action: [0.2913035]
# [Episode 28600] Success Rate: 82.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 28601, Total Reward: -0.59 action: [0.3403645]
# [Episode 28700] Success Rate: 49.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28701, Total Reward: -1.31 action: [0.29698765]
# [Episode 28800] Success Rate: 34.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 28801, Total Reward: -1.15 action: [0.30181146]
# [Episode 28900] Success Rate: 62.00%
# Episode: 28901, Total Reward: -0.77 action: [0.38916826]
# [Episode 29000] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29001, Total Reward: -1.30 action: [0.3273223]
# [Episode 29100] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29101, Total Reward: -0.67 action: [0.05426382]
# [Episode 29200] Success Rate: 77.00%
# Episode: 29201, Total Reward: -0.50 action: [-0.09262067]
# [Episode 29300] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29301, Total Reward: -1.85 action: [0.16671656]
# [Episode 29400] Success Rate: 17.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29401, Total Reward: -1.57 action: [0.07656366]
# [Episode 29500] Success Rate: 16.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29501, Total Reward: -1.04 action: [0.28073612]
# [Episode 29600] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29601, Total Reward: -1.58 action: [0.22047569]
# [Episode 29700] Success Rate: 29.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 29701, Total Reward: -0.19 action: [0.19525397]
# [Episode 29800] Success Rate: 67.00%
# Episode: 29801, Total Reward: -0.20 action: [0.18592753]
# [Episode 29900] Success Rate: 54.00%
# Episode: 29901, Total Reward: -0.78 action: [0.10875779]
# [Episode 30000] Success Rate: 40.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 30001, Total Reward: -0.68 action: [0.17059804]
# [Episode 30100] Success Rate: 72.00%
# Episode: 30101, Total Reward: -1.10 action: [0.45989755]
# [Episode 30200] Success Rate: 68.00%
# Episode: 30201, Total Reward: -1.03 action: [0.314057]
# [Episode 30300] Success Rate: 69.00%
# Episode: 30301, Total Reward: -0.80 action: [0.38052532]
# [Episode 30400] Success Rate: 90.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 30401, Total Reward: -0.70 action: [0.29565662]
# [Episode 30500] Success Rate: 66.00%
# Episode: 30501, Total Reward: -2.18 action: [0.222387]
# [Episode 30600] Success Rate: 70.00%
# Episode: 30601, Total Reward: -0.35 action: [0.17044479]
# [Episode 30700] Success Rate: 59.00%
# Episode: 30701, Total Reward: -0.57 action: [0.29982603]
# [Episode 30800] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 30801, Total Reward: -0.60 action: [0.1258531]
# [Episode 30900] Success Rate: 75.00%
# Episode: 30901, Total Reward: -0.69 action: [0.3619074]
# [Episode 31000] Success Rate: 71.00%
# Episode: 31001, Total Reward: -0.90 action: [0.36381716]
# [Episode 31100] Success Rate: 76.00%
# Episode: 31101, Total Reward: -0.73 action: [0.38122618]
# [Episode 31200] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 31201, Total Reward: -0.70 action: [-0.19910437]
# [Episode 31300] Success Rate: 7.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 31301, Total Reward: -0.67 action: [0.27410755]
# [Episode 31400] Success Rate: 60.00%
# Episode: 31401, Total Reward: -0.81 action: [0.38070554]
# [Episode 31500] Success Rate: 71.00%
# Episode: 31501, Total Reward: -2.23 action: [0.49074334]
# [Episode 31600] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 31601, Total Reward: -2.11 action: [0.29617253]
# [Episode 31700] Success Rate: 1.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 31701, Total Reward: -1.04 action: [0.3713329]
# [Episode 31800] Success Rate: 44.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 31801, Total Reward: -1.36 action: [0.2893168]
# [Episode 31900] Success Rate: 60.00%
# Episode: 31901, Total Reward: -1.15 action: [0.43397573]
# [Episode 32000] Success Rate: 47.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 32001, Total Reward: -1.38 action: [0.34751302]
# [Episode 32100] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 32101, Total Reward: -0.87 action: [0.31550452]
# [Episode 32200] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 32201, Total Reward: -1.37 action: [0.13852562]
# [Episode 32300] Success Rate: 65.00%
# Episode: 32301, Total Reward: -0.95 action: [0.43352336]
# [Episode 32400] Success Rate: 63.00%
# Episode: 32401, Total Reward: -0.18 action: [0.12682205]
# [Episode 32500] Success Rate: 79.00%
# Episode: 32501, Total Reward: -0.22 action: [0.19320661]
# [Episode 32600] Success Rate: 60.00%
# Episode: 32601, Total Reward: -0.23 action: [-0.05697779]
# [Episode 32700] Success Rate: 69.00%
# Episode: 32701, Total Reward: -0.29 action: [-0.18605134]
# [Episode 32800] Success Rate: 57.00%
# Episode: 32801, Total Reward: -0.30 action: [0.21778536]
# [Episode 32900] Success Rate: 86.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 32901, Total Reward: -0.54 action: [0.25872228]
# [Episode 33000] Success Rate: 85.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 33001, Total Reward: -0.44 action: [0.1458465]
# [Episode 33100] Success Rate: 75.00%
# Episode: 33101, Total Reward: -0.30 action: [0.18394858]
# [Episode 33200] Success Rate: 63.00%
# Episode: 33201, Total Reward: -0.58 action: [-0.02761145]
# [Episode 33300] Success Rate: 70.00%
# Episode: 33301, Total Reward: -0.67 action: [0.32799768]
# [Episode 33400] Success Rate: 78.00%
# Episode: 33401, Total Reward: -1.14 action: [0.44123462]
# [Episode 33500] Success Rate: 70.00%
# Episode: 33501, Total Reward: -0.29 action: [0.23943675]
# [Episode 33600] Success Rate: 79.00%
# Episode: 33601, Total Reward: -0.55 action: [0.30049136]
# [Episode 33700] Success Rate: 63.00%
# Episode: 33701, Total Reward: -0.15 action: [0.05448199]
# [Episode 33800] Success Rate: 71.00%
# Episode: 33801, Total Reward: -0.12 action: [0.05561827]
# [Episode 33900] Success Rate: 67.00%
# Episode: 33901, Total Reward: -0.91 action: [0.4243088]
# [Episode 34000] Success Rate: 78.00%
# Episode: 34001, Total Reward: -0.92 action: [0.2367782]
# [Episode 34100] Success Rate: 83.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 34101, Total Reward: -0.37 action: [0.26465407]
# [Episode 34200] Success Rate: 75.00%
# Episode: 34201, Total Reward: -0.25 action: [0.12037404]
# [Episode 34300] Success Rate: 58.00%
# Episode: 34301, Total Reward: -0.54 action: [0.30616286]
# [Episode 34400] Success Rate: 89.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 34401, Total Reward: -0.00 action: [-0.0107564]
# [Episode 34500] Success Rate: 94.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 34501, Total Reward: -0.27 action: [0.21621886]
# [Episode 34600] Success Rate: 81.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 34601, Total Reward: -2.91 action: [0.133442]
# [Episode 34700] Success Rate: 50.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 34701, Total Reward: -0.22 action: [0.15618932]
# [Episode 34800] Success Rate: 50.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 34801, Total Reward: -2.67 action: [-0.07575141]
# [Episode 34900] Success Rate: 10.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 34901, Total Reward: -1.38 action: [0.13566288]
# [Episode 35000] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 35001, Total Reward: -2.51 action: [0.20828351]
# [Episode 35100] Success Rate: 65.00%
# Episode: 35101, Total Reward: -0.09 action: [0.12709254]
# [Episode 35200] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 35201, Total Reward: -0.60 action: [0.25589362]
# [Episode 35300] Success Rate: 81.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 35301, Total Reward: -0.41 action: [0.2686721]
# [Episode 35400] Success Rate: 99.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 35401, Total Reward: -1.43 action: [0.48021418]
# [Episode 35500] Success Rate: 70.00%
# Episode: 35501, Total Reward: -0.03 action: [0.05017041]
# [Episode 35600] Success Rate: 63.00%
# Episode: 35601, Total Reward: -0.57 action: [0.00338304]
# [Episode 35700] Success Rate: 24.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 35701, Total Reward: -0.02 action: [-0.01828193]
# [Episode 35800] Success Rate: 74.00%
# Episode: 35801, Total Reward: -0.21 action: [0.14151677]
# [Episode 35900] Success Rate: 58.00%
# Episode: 35901, Total Reward: -0.69 action: [0.34505492]
# [Episode 36000] Success Rate: 62.00%
# Episode: 36001, Total Reward: -0.50 action: [-0.04498741]
# [Episode 36100] Success Rate: 84.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 36101, Total Reward: -0.27 action: [0.23024869]
# [Episode 36200] Success Rate: 69.00%
# Episode: 36201, Total Reward: -0.88 action: [0.2450191]
# [Episode 36300] Success Rate: 66.00%
# Episode: 36301, Total Reward: -0.44 action: [0.06724011]
# [Episode 36400] Success Rate: 47.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 36401, Total Reward: -1.14 action: [0.00980933]
# [Episode 36500] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 36501, Total Reward: -2.17 action: [0.16269486]
# [Episode 36600] Success Rate: 43.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 36601, Total Reward: -0.14 action: [0.14859283]
# [Episode 36700] Success Rate: 89.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 36701, Total Reward: -4.87 action: [0.9843992]
# [Episode 36800] Success Rate: 62.00%
# Episode: 36801, Total Reward: -0.20 action: [0.15054779]
# [Episode 36900] Success Rate: 24.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 36901, Total Reward: -0.42 action: [0.15638344]
# [Episode 37000] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 37001, Total Reward: -1.42 action: [0.34839544]
# [Episode 37100] Success Rate: 79.00%
# Episode: 37101, Total Reward: -0.07 action: [0.1110746]
# [Episode 37200] Success Rate: 67.00%
# Episode: 37201, Total Reward: -0.03 action: [0.04308788]
# [Episode 37300] Success Rate: 62.00%
# Episode: 37301, Total Reward: -0.49 action: [0.26667827]
# [Episode 37400] Success Rate: 82.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 37401, Total Reward: -0.98 action: [0.4387303]
# [Episode 37500] Success Rate: 95.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 37501, Total Reward: -0.50 action: [0.2997267]
# [Episode 37600] Success Rate: 88.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 37601, Total Reward: -0.42 action: [0.23533185]
# [Episode 37700] Success Rate: 87.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 37701, Total Reward: -0.02 action: [-0.03225916]
# [Episode 37800] Success Rate: 71.00%
# Episode: 37801, Total Reward: -0.82 action: [0.37801453]
# [Episode 37900] Success Rate: 72.00%
# Episode: 37901, Total Reward: -0.30 action: [0.2227056]
# [Episode 38000] Success Rate: 74.00%
# Episode: 38001, Total Reward: -0.20 action: [-0.06219371]
# [Episode 38100] Success Rate: 61.00%
# Episode: 38101, Total Reward: -0.63 action: [0.33833164]
# [Episode 38200] Success Rate: 83.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 38201, Total Reward: -0.08 action: [0.01344895]
# [Episode 38300] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 38301, Total Reward: -0.29 action: [0.17312877]
# [Episode 38400] Success Rate: 75.00%
# Episode: 38401, Total Reward: -0.24 action: [0.21601698]
# [Episode 38500] Success Rate: 72.00%
# Episode: 38501, Total Reward: -0.59 action: [0.330446]
# [Episode 38600] Success Rate: 83.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 38601, Total Reward: -0.18 action: [0.00463574]
# [Episode 38700] Success Rate: 66.00%
# Episode: 38701, Total Reward: -0.37 action: [0.27018425]
# [Episode 38800] Success Rate: 53.00%
# Episode: 38801, Total Reward: -0.82 action: [0.35232434]
# [Episode 38900] Success Rate: 81.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 38901, Total Reward: -3.39 action: [0.74786514]
# [Episode 39000] Success Rate: 77.00%
# Episode: 39001, Total Reward: -0.13 action: [0.11821273]
# [Episode 39100] Success Rate: 77.00%
# Episode: 39101, Total Reward: -0.21 action: [-0.20685917]
# [Episode 39200] Success Rate: 68.00%
# Episode: 39201, Total Reward: -0.70 action: [0.1508374]
# [Episode 39300] Success Rate: 72.00%
# Episode: 39301, Total Reward: -0.86 action: [0.30796674]
# [Episode 39400] Success Rate: 74.00%
# Episode: 39401, Total Reward: -0.27 action: [-0.104636]
# [Episode 39500] Success Rate: 77.00%
# Episode: 39501, Total Reward: -0.15 action: [-0.13045964]
# [Episode 39600] Success Rate: 62.00%
# Episode: 39601, Total Reward: -0.73 action: [0.09003356]
# [Episode 39700] Success Rate: 56.00%
# Episode: 39701, Total Reward: -0.23 action: [0.11093575]
# [Episode 39800] Success Rate: 74.00%
# Episode: 39801, Total Reward: -0.19 action: [0.1943239]
# [Episode 39900] Success Rate: 72.00%
# Episode: 39901, Total Reward: -0.26 action: [-0.1697941]
# [Episode 40000] Success Rate: 61.00%
# Episode: 40001, Total Reward: -2.48 action: [0.15006255]
# [Episode 40100] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 40101, Total Reward: -0.81 action: [0.38193214]
# [Episode 40200] Success Rate: 75.00%
# Episode: 40201, Total Reward: -1.02 action: [0.28881156]
# [Episode 40300] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 40301, Total Reward: -0.03 action: [-0.05417219]
# [Episode 40400] Success Rate: 36.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 40401, Total Reward: -0.20 action: [0.0428665]
# [Episode 40500] Success Rate: 54.00%
# Episode: 40501, Total Reward: -0.31 action: [0.24346513]
# [Episode 40600] Success Rate: 62.00%
# Episode: 40601, Total Reward: -0.12 action: [0.12894581]
# [Episode 40700] Success Rate: 72.00%
# Episode: 40701, Total Reward: -0.91 action: [0.09744344]
# [Episode 40800] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 40801, Total Reward: -4.74 action: [-0.18806323]
# [Episode 40900] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 40901, Total Reward: -0.44 action: [0.17994192]
# [Episode 41000] Success Rate: 69.00%
# Episode: 41001, Total Reward: -0.07 action: [0.06256402]
# [Episode 41100] Success Rate: 75.00%
# Episode: 41101, Total Reward: -1.55 action: [0.5306992]
# [Episode 41200] Success Rate: 78.00%
# Episode: 41201, Total Reward: -0.13 action: [0.1294581]
# [Episode 41300] Success Rate: 35.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 41301, Total Reward: -0.37 action: [0.26535]
# [Episode 41400] Success Rate: 77.00%
# Episode: 41401, Total Reward: -2.58 action: [0.706222]
# [Episode 41500] Success Rate: 57.00%
# Episode: 41501, Total Reward: -0.43 action: [0.05353713]
# [Episode 41600] Success Rate: 57.00%
# Episode: 41601, Total Reward: -0.37 action: [-0.12128625]
# [Episode 41700] Success Rate: 54.00%
# Episode: 41701, Total Reward: -0.35 action: [0.10805757]
# [Episode 41800] Success Rate: 59.00%
# Episode: 41801, Total Reward: -0.27 action: [0.0021476]
# [Episode 41900] Success Rate: 77.00%
# Episode: 41901, Total Reward: -0.24 action: [-0.00346881]
# [Episode 42000] Success Rate: 78.00%
# Episode: 42001, Total Reward: -0.28 action: [0.08033371]
# [Episode 42100] Success Rate: 90.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 42101, Total Reward: -0.11 action: [0.13966876]
# [Episode 42200] Success Rate: 94.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 42201, Total Reward: -0.10 action: [-0.03300315]
# [Episode 42300] Success Rate: 68.00%
# Episode: 42301, Total Reward: -3.05 action: [-0.05332596]
# [Episode 42400] Success Rate: 43.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 42401, Total Reward: -4.82 action: [0.9141988]
# [Episode 42500] Success Rate: 80.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 42501, Total Reward: -0.35 action: [0.10736275]
# [Episode 42600] Success Rate: 56.00%
# Episode: 42601, Total Reward: -0.05 action: [0.10037819]
# [Episode 42700] Success Rate: 73.00%
# Episode: 42701, Total Reward: -0.10 action: [0.11038015]
# [Episode 42800] Success Rate: 63.00%
# Episode: 42801, Total Reward: -0.16 action: [-0.0989133]
# [Episode 42900] Success Rate: 64.00%
# Episode: 42901, Total Reward: -0.20 action: [-0.12399149]
# [Episode 43000] Success Rate: 62.00%
# Episode: 43001, Total Reward: -0.30 action: [-0.22762941]
# [Episode 43100] Success Rate: 79.00%
# Episode: 43101, Total Reward: -0.11 action: [0.06549716]
# [Episode 43200] Success Rate: 45.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 43201, Total Reward: -28.28 action: [2.371495]
# [Episode 43300] Success Rate: 45.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 43301, Total Reward: -0.38 action: [-0.13414407]
# [Episode 43400] Success Rate: 19.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 43401, Total Reward: -2.15 action: [0.35395935]
# [Episode 43500] Success Rate: 21.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 43501, Total Reward: -0.55 action: [0.08384053]
# [Episode 43600] Success Rate: 67.00%
# Episode: 43601, Total Reward: -0.18 action: [0.05153437]
# [Episode 43700] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 43701, Total Reward: -0.08 action: [0.00729743]
# [Episode 43800] Success Rate: 81.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 43801, Total Reward: -0.79 action: [-0.39665073]
# [Episode 43900] Success Rate: 25.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 43901, Total Reward: -3.85 action: [-0.8602253]
# [Episode 44000] Success Rate: 42.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44001, Total Reward: -6.77 action: [-1.1275973]
# [Episode 44100] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44101, Total Reward: -2.11 action: [-0.5081266]
# [Episode 44200] Success Rate: 20.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44201, Total Reward: -0.87 action: [-0.41618538]
# [Episode 44300] Success Rate: 95.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 44301, Total Reward: -1.07 action: [-0.41806054]
# [Episode 44400] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44401, Total Reward: -25.52 action: [0.38560548]
# [Episode 44500] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44501, Total Reward: -0.15 action: [-0.09152213]
# [Episode 44600] Success Rate: 10.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44601, Total Reward: -2.26 action: [0.43396237]
# [Episode 44700] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44701, Total Reward: -2.52 action: [0.3315593]
# [Episode 44800] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44801, Total Reward: -3.50 action: [0.74622935]
# [Episode 44900] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 44901, Total Reward: -1.09 action: [0.32307044]
# [Episode 45000] Success Rate: 26.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 45001, Total Reward: -1.78 action: [0.23866457]
# [Episode 45100] Success Rate: 36.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 45101, Total Reward: -2.33 action: [-0.2725336]
# [Episode 45200] Success Rate: 24.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 45201, Total Reward: -7.90 action: [-0.13331462]
# [Episode 45300] Success Rate: 37.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 45301, Total Reward: -0.03 action: [0.05007656]
# [Episode 45400] Success Rate: 54.00%
# Episode: 45401, Total Reward: -0.68 action: [-0.03648042]
# [Episode 45500] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 45501, Total Reward: -4.08 action: [0.48728243]
# [Episode 45600] Success Rate: 13.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 45601, Total Reward: -3.41 action: [0.4092343]
# [Episode 45700] Success Rate: 51.00%
# Episode: 45701, Total Reward: -0.05 action: [-0.08223999]
# [Episode 45800] Success Rate: 76.00%
# Episode: 45801, Total Reward: -0.05 action: [0.01647182]
# [Episode 45900] Success Rate: 53.00%
# Episode: 45901, Total Reward: -0.14 action: [-0.1116948]
# [Episode 46000] Success Rate: 32.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46001, Total Reward: -24.04 action: [2.1628966]
# [Episode 46100] Success Rate: 57.00%
# Episode: 46101, Total Reward: -0.31 action: [-0.18250322]
# [Episode 46200] Success Rate: 69.00%
# Episode: 46201, Total Reward: -0.48 action: [-0.10618787]
# [Episode 46300] Success Rate: 8.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46301, Total Reward: -3.29 action: [0.07117552]
# [Episode 46400] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46401, Total Reward: -0.57 action: [-0.09539701]
# [Episode 46500] Success Rate: 22.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46501, Total Reward: -0.59 action: [-0.03756245]
# [Episode 46600] Success Rate: 55.00%
# Episode: 46601, Total Reward: -1.16 action: [0.41749716]
# [Episode 46700] Success Rate: 9.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46701, Total Reward: -1.48 action: [0.351852]
# [Episode 46800] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46801, Total Reward: -0.07 action: [0.04081257]
# [Episode 46900] Success Rate: 1.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 46901, Total Reward: -25.70 action: [0.8391388]
# [Episode 47000] Success Rate: 14.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47001, Total Reward: -21.01 action: [1.9901434]
# [Episode 47100] Success Rate: 20.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47101, Total Reward: -0.01 action: [-0.00542735]
# [Episode 47200] Success Rate: 72.00%
# Episode: 47201, Total Reward: -0.08 action: [-0.05243939]
# [Episode 47300] Success Rate: 23.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47301, Total Reward: -3.41 action: [0.1437429]
# [Episode 47400] Success Rate: 25.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47401, Total Reward: -0.21 action: [0.11861405]
# [Episode 47500] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47501, Total Reward: -0.43 action: [0.04037672]
# [Episode 47600] Success Rate: 51.00%
# Episode: 47601, Total Reward: -1.14 action: [0.12775192]
# [Episode 47700] Success Rate: 6.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47701, Total Reward: -1.54 action: [0.39901465]
# [Episode 47800] Success Rate: 24.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 47801, Total Reward: -0.30 action: [0.21049176]
# [Episode 47900] Success Rate: 80.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 47901, Total Reward: -0.33 action: [0.07718511]
# [Episode 48000] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 48001, Total Reward: -4.67 action: [0.00829246]
# [Episode 48100] Success Rate: 57.00%
# Episode: 48101, Total Reward: -0.24 action: [0.21080169]
# [Episode 48200] Success Rate: 58.00%
# Episode: 48201, Total Reward: -0.50 action: [0.01500508]
# [Episode 48300] Success Rate: 80.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 48301, Total Reward: -0.05 action: [0.08447881]
# [Episode 48400] Success Rate: 85.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 48401, Total Reward: -0.05 action: [-0.05494605]
# [Episode 48500] Success Rate: 90.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 48501, Total Reward: -0.09 action: [-0.03357338]
# [Episode 48600] Success Rate: 87.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 48601, Total Reward: -0.15 action: [0.0356626]
# [Episode 48700] Success Rate: 71.00%
# Episode: 48701, Total Reward: -0.02 action: [0.06182429]
# [Episode 48800] Success Rate: 75.00%
# Episode: 48801, Total Reward: -0.03 action: [-0.08311769]
# [Episode 48900] Success Rate: 77.00%
# Episode: 48901, Total Reward: -0.06 action: [0.07750743]
# [Episode 49000] Success Rate: 48.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 49001, Total Reward: -2.50 action: [-0.08997044]
# [Episode 49100] Success Rate: 53.00%
# Episode: 49101, Total Reward: -0.97 action: [0.33931667]
# [Episode 49200] Success Rate: 73.00%
# Episode: 49201, Total Reward: -0.59 action: [0.00371024]
# [Episode 49300] Success Rate: 67.00%
# Episode: 49301, Total Reward: -0.21 action: [0.00503268]
# [Episode 49400] Success Rate: 52.00%
# Episode: 49401, Total Reward: -1.08 action: [0.0426707]
# [Episode 49500] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 49501, Total Reward: -0.54 action: [0.15254703]
# [Episode 49600] Success Rate: 63.00%
# Episode: 49601, Total Reward: -0.41 action: [0.2258141]
# [Episode 49700] Success Rate: 60.00%
# Episode: 49701, Total Reward: -0.11 action: [0.08185982]
# [Episode 49800] Success Rate: 100.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 49801, Total Reward: -0.06 action: [-0.00599168]
# [Episode 49900] Success Rate: 57.00%
# Episode: 49901, Total Reward: -0.88 action: [0.2096802]
# [Episode 50000] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 50001, Total Reward: -0.87 action: [0.23565947]
# [Episode 50100] Success Rate: 25.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 50101, Total Reward: -0.09 action: [0.02517043]
# [Episode 50200] Success Rate: 10.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 50201, Total Reward: -0.59 action: [0.2780636]
# [Episode 50300] Success Rate: 68.00%
# Episode: 50301, Total Reward: -0.16 action: [0.0578839]
# [Episode 50400] Success Rate: 78.00%
# Episode: 50401, Total Reward: -0.41 action: [0.19358519]
# [Episode 50500] Success Rate: 68.00%
# Episode: 50501, Total Reward: -0.34 action: [0.12294106]
# [Episode 50600] Success Rate: 83.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 50601, Total Reward: -0.36 action: [0.22025762]
# [Episode 50700] Success Rate: 83.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 50701, Total Reward: -10.16 action: [0.07384484]
# [Episode 50800] Success Rate: 41.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 50801, Total Reward: -0.37 action: [0.26300108]
# [Episode 50900] Success Rate: 86.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 50901, Total Reward: -0.46 action: [0.13939442]
# [Episode 51000] Success Rate: 89.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# ...
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 169001, Total Reward: -3.00 action: [-0.04656596]
# [Episode 169100] Success Rate: 34.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 169101, Total Reward: -0.90 action: [0.38330007]
# [Episode 169200] Success Rate: 55.00%
# Episode: 169201, Total Reward: -2.93 action: [0.14795573]
# [Episode 169300] Success Rate: 37.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 169301, Total Reward: -0.62 action: [0.33377615]
# [Episode 169400] Success Rate: 88.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 169401, Total Reward: -0.30 action: [-0.11323086]
# [Episode 169500] Success Rate: 59.00%
# Episode: 169501, Total Reward: -1.59 action: [0.08443854]
# [Episode 169600] Success Rate: 37.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 169601, Total Reward: -0.77 action: [0.03592001]
# [Episode 169700] Success Rate: 68.00%
# Episode: 169701, Total Reward: -0.08 action: [-0.1131047]
# [Episode 169800] Success Rate: 89.00%
# -> 躍度ペナルティ重みを増加: 0.00000
# Episode: 169801, Total Reward: -0.16 action: [0.09908482]
# [Episode 169900] Success Rate: 67.00%
# Episode: 169901, Total Reward: -0.27 action: [0.08011442]
# [Episode 170000] Success Rate: 68.00%
# Episode: 170001, Total Reward: -0.32 action: [-0.1621802]
# [Episode 170100] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 170101, Total Reward: -0.76 action: [-0.286503]
# [Episode 170200] Success Rate: 72.00%
# Episode: 170201, Total Reward: -0.52 action: [0.06951492]
# [Episode 170300] Success Rate: 20.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 170301, Total Reward: -0.37 action: [-0.18244717]
# [Episode 170400] Success Rate: 57.00%
# Episode: 170401, Total Reward: -0.02 action: [-0.04041428]
# [Episode 170500] Success Rate: 69.00%
# Episode: 170501, Total Reward: -2.90 action: [-0.13875343]
# [Episode 170600] Success Rate: 39.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 170601, Total Reward: -1.66 action: [-0.17476135]
# [Episode 170700] Success Rate: 45.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 170701, Total Reward: -1.20 action: [-0.22718483]
# [Episode 170800] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 170801, Total Reward: -0.89 action: [-0.2858214]
# [Episode 170900] Success Rate: 6.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 170901, Total Reward: -0.48 action: [0.22616646]
# [Episode 171000] Success Rate: 44.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171001, Total Reward: -2.90 action: [-0.038875]
# [Episode 171100] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171101, Total Reward: -0.28 action: [0.07109778]
# [Episode 171200] Success Rate: 67.00%
# Episode: 171201, Total Reward: -1.41 action: [0.3687318]
# [Episode 171300] Success Rate: 10.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171301, Total Reward: -0.42 action: [0.06969615]
# [Episode 171400] Success Rate: 67.00%
# Episode: 171401, Total Reward: -0.10 action: [-0.11005278]
# [Episode 171500] Success Rate: 18.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171501, Total Reward: -2.74 action: [-0.21622385]
# [Episode 171600] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171601, Total Reward: -4.84 action: [-0.47603288]
# [Episode 171700] Success Rate: 17.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171701, Total Reward: -0.55 action: [0.12758377]
# [Episode 171800] Success Rate: 73.00%
# Episode: 171801, Total Reward: -0.43 action: [0.27495438]
# [Episode 171900] Success Rate: 20.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 171901, Total Reward: -1.97 action: [-0.00239588]
# [Episode 172000] Success Rate: 28.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172001, Total Reward: -3.08 action: [-0.08569044]
# [Episode 172100] Success Rate: 8.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172101, Total Reward: -0.15 action: [-0.11575858]
# [Episode 172200] Success Rate: 30.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172201, Total Reward: -5.70 action: [0.08329812]
# [Episode 172300] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172301, Total Reward: -4.07 action: [0.25403905]
# [Episode 172400] Success Rate: 27.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172401, Total Reward: -0.08 action: [-0.11456036]
# [Episode 172500] Success Rate: 71.00%
# Episode: 172501, Total Reward: -1.10 action: [0.02761457]
# [Episode 172600] Success Rate: 13.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172601, Total Reward: -4.62 action: [0.02163773]
# [Episode 172700] Success Rate: 5.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172701, Total Reward: -0.73 action: [-0.13445978]
# [Episode 172800] Success Rate: 3.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172801, Total Reward: -6.25 action: [-0.03231252]
# [Episode 172900] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 172901, Total Reward: -3.49 action: [-0.145662]
# [Episode 173000] Success Rate: 0.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173001, Total Reward: -2.84 action: [0.15055665]
# [Episode 173100] Success Rate: 13.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173101, Total Reward: -3.11 action: [0.22437008]
# [Episode 173200] Success Rate: 4.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173201, Total Reward: -1.08 action: [-0.0129761]
# [Episode 173300] Success Rate: 15.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173301, Total Reward: -3.04 action: [-0.43553036]
# [Episode 173400] Success Rate: 10.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173401, Total Reward: -1.10 action: [0.02891869]
# [Episode 173500] Success Rate: 9.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173501, Total Reward: -0.57 action: [0.05096946]
# [Episode 173600] Success Rate: 31.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173601, Total Reward: -1.65 action: [-0.13046396]
# [Episode 173700] Success Rate: 41.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173701, Total Reward: -0.08 action: [0.07902797]
# [Episode 173800] Success Rate: 52.00%
# Episode: 173801, Total Reward: -1.29 action: [-0.08538225]
# [Episode 173900] Success Rate: 31.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 173901, Total Reward: -3.22 action: [0.4027474]
# [Episode 174000] Success Rate: 13.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 174001, Total Reward: -0.65 action: [0.2592658]
# [Episode 174100] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 174101, Total Reward: -0.33 action: [-0.05650454]
# [Episode 174200] Success Rate: 41.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 174201, Total Reward: -0.73 action: [0.00617192]
# [Episode 174300] Success Rate: 33.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 174301, Total Reward: -2.14 action: [0.0846018]
# [Episode 174400] Success Rate: 1.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 174401, Total Reward: -2.12 action: [0.07697412]
# [Episode 174500] Success Rate: 11.00%
# -> 躍度ペナルティ重みを減少: 0.00000
# Episode: 174501, Total Reward: -0.19 action: [0.16471575]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 model, history_rewards21, history_metrics, history_metrics_y = train_main()
#
# Cell In[98], line 84, in train_main()
#      76 replay_buffer.append({
#      77     "state": state,
#      78     "action": pre_tanh,
#    (...)
#      81     "done": done,
#      82 })
#      83 if len(replay_buffer) >= WARMUP_SIZE and total_steps % TRAIN_INTARVAL == 0:
# ---> 84     metrics = update_model(
#      85         policy_model, q_model, target_q_model,
#      86         replay_buffer, BATCH_SIZE, SIGMA,
#      87         log_alpha, alpha_optimizer,
#      88         soft_target_tau=0.02, hard_target_interval=100,
#      89         target_entropy=target_entropy,
#      90         all_train_count=train_count
#      91     )
#      92     train_count += 1
#      93     metrics_list.append(metrics)
#
# Cell In[97], line 62, in update_model(policy_model, q_model, target_q_model, experiences, BATCH_SIZE, SIGMA, log_alpha, log_alpha_optimizer, soft_target_tau, hard_target_interval, target_entropy, all_train_count)
#      59     q_loss = loss1 + loss2#何で和を取るの？
#      61 grads = tape.gradient(q_loss, q_model.trainable_variables)
# ---> 62 q_model.optimizer.apply_gradients(zip(grads, q_model.trainable_variables))
#      64 # --- ポリシーの学習
#      65 with tf.GradientTape() as tape:
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/optimizers/base_optimizer.py:383, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     381 def apply_gradients(self, grads_and_vars):
#     382     grads, trainable_variables = zip(*grads_and_vars)
# --> 383     self.apply(grads, trainable_variables)
#     384     # Return iterations for compat with tf.keras.
#     385     return self._iterations
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/optimizers/base_optimizer.py:448, in BaseOptimizer.apply(self, grads, trainable_variables)
#     445     grads = [g if g is None else g / scale for g in grads]
#     447 # Apply gradient updates.
# --> 448 self._backend_apply_gradients(grads, trainable_variables)
#     449 # Apply variable constraints after applying gradients.
#     450 for variable in trainable_variables:
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/optimizers/base_optimizer.py:511, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     508     self._apply_weight_decay(trainable_variables)
#     510     # Run update step.
# --> 511     self._backend_update_step(
#     512         grads, trainable_variables, self.learning_rate
#     513     )
#     515 if self.use_ema:
#     516     self._update_model_variables_moving_average(
#     517         self._trainable_variables
#     518     )
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/optimizer.py:120, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     118 grads_and_vars = list(zip(grads, trainable_variables))
#     119 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 120 tf.__internal__.distribute.interim.maybe_merge_call(
#     121     self._distributed_tf_update_step,
#     122     self._distribution_strategy,
#     123     grads_and_vars,
#     124     learning_rate,
#     125 )
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/tensorflow/python/distribute/merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/optimizer.py:134, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     131     return self.update_step(grad, var, learning_rate)
#     133 for grad, var in grads_and_vars:
# --> 134     distribution.extended.update(
#     135         var,
#     136         apply_grad_to_update_var,
#     137         args=(grad, learning_rate),
#     138         group=False,
#     139     )
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/optimizer.py:131, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     130 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 131     return self.update_step(grad, var, learning_rate)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/optimizers/adam.py:137, in Adam.update_step(self, gradient, variable, learning_rate)
#     130 alpha = lr * ops.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     132 self.assign_add(
#     133     m, ops.multiply(ops.subtract(gradient, m), 1 - self.beta_1)
#     134 )
#     135 self.assign_add(
#     136     v,
# --> 137     ops.multiply(
#     138         ops.subtract(ops.square(gradient), v), 1 - self.beta_2
#     139     ),
#     140 )
#     141 if self.amsgrad:
#     142     v_hat = self._velocity_hats[self._get_variable_index(variable)]
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/ops/numpy.py:6112, in multiply(x1, x2)
#    6110 if any_symbolic_tensors((x1, x2)):
#    6111     return Multiply().symbolic_call(x1, x2)
# -> 6112 return backend.numpy.multiply(x1, x2)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/sparse.py:627, in elementwise_binary_intersection.<locals>.sparse_wrapper(x1, x2)
#     621         return tf.IndexedSlices(
#     622             func(tf.gather(x1, x2.indices), x2.values),
#     623             x2.indices,
#     624             x2.dense_shape,
#     625         )
#     626 # Default case, no SparseTensor and no IndexedSlices.
# --> 627 return func(x1, x2)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/numpy.py:590, in multiply(x1, x2)
#     585     x2 = convert_to_tensor(x2)
#     586 dtype = dtypes.result_type(
#     587     getattr(x1, "dtype", type(x1)),
#     588     getattr(x2, "dtype", type(x2)),
#     589 )
# --> 590 x1 = convert_to_tensor(x1, dtype)
#     591 x2 = convert_to_tensor(x2, dtype)
#     592 return tf.multiply(x1, x2)
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/tensorflow/core.py:132, in convert_to_tensor(x, dtype, sparse, ragged)
#     130     x = x.to_tensor()
#     131 if dtype is not None:
# --> 132     dtype = standardize_dtype(dtype)
#     133 if not tf.is_tensor(x):
#     134     if dtype == "bool" or is_int_dtype(dtype):
#     135         # TensorFlow conversion is stricter than other backends, it does not
#     136         # allow ints for bools or floats for ints. We convert without dtype
#     137         # and cast instead.
#
# File ~/2503-nishida-bachelor-thesis/.venv/lib/python3.9/site-packages/keras/src/backend/common/variables.py:546, in standardize_dtype(dtype)
#     543 if hasattr(dtype, "name"):
#     544     dtype = dtype.name
#     545 elif hasattr(dtype, "__str__") and (
# --> 546     "torch" in str(dtype) or "jax.numpy" in str(dtype)
#     547 ):
#     548     dtype = str(dtype).split(".")[-1]
#     549 elif hasattr(dtype, "__name__"):
#
# KeyboardInterrupt:

# %%
fig, ax1 = plt.subplots()

ax1.set_xlabel('episode')
ax1.grid()
ax1.plot(history_metrics_y, [m[0] for m in history_metrics], color="C0", marker='.', label="policy_loss")
ax1.legend(loc='upper left')

ax2 = ax1.twinx()
ax2.plot(history_metrics_y, [m[1] for m in history_metrics], color="C1", marker='.', label="q_loss")
ax2.legend(loc='upper right')

fig.tight_layout()  # レイアウトの設定
#plt.savefig('cartp
# ole2.png') # 画像の保存
plt.show()
